# %% [markdown]
# # Visualization attempts

# %%
import pandas as pd
import matplotlib.pyplot as plt
import my_tools as tools

df_cases_new = pd.read_csv('data/cases_new.csv')
df_cases_new.name= 'New cases'
df_cases_total = pd.read_csv('data/cases_total.csv')
df_cases_total.name = 'Total cases'

df_deaths_new = pd.read_csv('data/deaths_new.csv')
df_deaths_new.name = 'New deaths'
df_deaths_total = pd.read_csv('data/deaths_total.csv')
df_deaths_total.name = 'Total deaths'

df_population = pd.read_csv('data/population_total.csv')
df_population.name = 'Population'
df_population_dens = pd.read_csv('data/population_density_per_square_km.csv')
df_population_dens.name = 'Population density, per square km'

# %%
tools.plot_side_by_side(df_cases_new, df_cases_total)

# %%
tools.plot_side_by_side(df_deaths_new, df_deaths_total)
