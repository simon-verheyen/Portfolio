# %% [markdown]
# # Alarm bell

# %%
import my_tools as mt
import matplotlib.pyplot as plt

df_prevalence = mt.read_csv('prevalence', 'Prevalence').drop(['Cases on an international conveyance Japan'], axis=1)
df_incidence_daily = mt.read_csv('incidence_daily', 'Incidence daily').drop(['Cases on an international conveyance Japan'], axis=1)
df_incidence_weekly = mt.read_csv('incidence_weekly', 'Incidence weekly').drop(['Cases on an international conveyance Japan'], axis=1)

df_mortality = mt.read_csv('mortality', 'Mortality')

# %%
df_prevalence.plot(legend=False, figsize=(17,9))
plt.show()
df_incidence_daily.plot(legend=False, figsize=(17,9))
plt.show()
df_incidence_weekly.plot(legend=False, figsize=(17,9))
plt.show()
df_mortality.plot(legend=False, figsize=(17,9))
plt.show()
