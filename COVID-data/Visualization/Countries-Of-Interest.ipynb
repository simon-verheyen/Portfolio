# %% [markdown]
# # Countries of interest

# %%
import my_tools as mt

countries_of_interest = ['China', 'France', 'Italy', 'United States of America', 'Spain', 
                         'United Kingdom', 'Belgium', 'Iran', 'Ukraine', 'South Korea']
countries_of_interest.sort()

# %%
mt.plot_spread('cases', '3days', countries_of_interest)
mt.plot_spread('cases', '3days', countries_of_interest, scale='log')

# %%
mt.plot_spread('cases', 'total', countries_of_interest)
mt.plot_spread('cases', 'total', countries_of_interest, scale='log')

# %%
countries_of_interest.append('Global')

mt.plot_spread('incidence', '3days', countries_of_interest)
mt.plot_spread('incidence', '3days', countries_of_interest, scale='log')

# %%
mt.plot_trends_dynamically('countries_of_interest', countries_of_interest)
# Out:
# No handles with labels found to put in legend.

# %%
mt.show_table(countries_of_interest)
# Out:
# <style  type="text/css" >
# </style><table id="T_67e46062_78e1_11ea_a394_b59b8321deba" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Today</th>        <th class="col_heading level0 col1" >3 day av</th>        <th class="col_heading level0 col2" >Weekly av</th>        <th class="col_heading level0 col3" >Incidence today</th>        <th class="col_heading level0 col4" >Incidence 3day av</th>        <th class="col_heading level0 col5" >Incidence weekly av</th>        <th class="col_heading level0 col6" >Total</th>        <th class="col_heading level0 col7" >Prevalence</th>        <th class="col_heading level0 col8" >Mortality</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_67e46062_78e1_11ea_a394_b59b8321debalevel0_row0" class="row_heading level0 row0" rowspan=2>Belgium</th>
# ...
