# %% [markdown]
# # Countries with the highest impact
#
# This worksheet is part of a project to analyse and visualise data on the COVID-19 outbreak and will be run once a day.<br>
# It shows the data from a list of countries made by taking the intersection of the 10 countries with the highest incidence and the 10 countries with the highest prevalence. Both over the last week.
#
# To view this page in a bigger format, please right-click [here](https://github.com/simon-verheyen/Portfolio/tree/master/COVID-data) and open in a new tab.

# %%
import my_tools as mt

amount_days = 6 * 7
countries = mt.find_crit('impacted')
# Out:
# Latest update at 2020-04-10

# %% [markdown]
# ### Table
#
# This table holds the latest information on each of the countries.
#
# - Incidence = New cases / Population
# - Prevalence = Total cases / Population

# %%
mt.show_table(countries)
# Out:
# <style  type="text/css" >
# </style><table id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total</th>        <th class="col_heading level0 col1" >Prevalence</th>        <th class="col_heading level0 col2" >Mortality</th>        <th class="col_heading level0 col3" >Today</th>        <th class="col_heading level0 col4" >3 days av</th>        <th class="col_heading level0 col5" >Weekly av</th>        <th class="col_heading level0 col6" >Incidence today</th>        <th class="col_heading level0 col7" >Incidence 3 days av</th>        <th class="col_heading level0 col8" >Incidence weekly av</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1level0_row0" class="row_heading level0 row0" rowspan=2>Global</th>
#                         <th id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1level1_row0" class="row_heading level1 row0" >Cases</th>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row0_col0" class="data row0 col0" >1476819</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row0_col1" class="data row0 col1" >0.020%</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row0_col2" class="data row0 col2" ></td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row0_col3" class="data row0 col3" >84930</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row0_col4" class="data row0 col4" >77074</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row0_col5" class="data row0 col5" >78332</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row0_col6" class="data row0 col6" >0.001%</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row0_col7" class="data row0 col7" >0.001%</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row0_col8" class="data row0 col8" >0.001%</td>
#             </tr>
#             <tr>
#                                 <th id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1level1_row1" class="row_heading level1 row1" >Deaths</th>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row1_col0" class="data row1 col0" >87816</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row1_col1" class="data row1 col1" ></td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row1_col2" class="data row1 col2" >5.946%</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row1_col3" class="data row1 col3" >6339</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row1_col4" class="data row1 col4" >6296</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row1_col5" class="data row1 col5" >5847</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row1_col6" class="data row1 col6" ></td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row1_col7" class="data row1 col7" ></td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row1_col8" class="data row1 col8" ></td>
#             </tr>
#             <tr>
#                         <th id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1level0_row2" class="row_heading level0 row2" rowspan=2>Andorra</th>
#                         <th id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1level1_row2" class="row_heading level1 row2" >Cases</th>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row2_col0" class="data row2 col0" >564</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row2_col1" class="data row2 col1" >0.732%</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row2_col2" class="data row2 col2" ></td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row2_col3" class="data row2 col3" >19</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row2_col4" class="data row2 col4" >21</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row2_col5" class="data row2 col5" >24</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row2_col6" class="data row2 col6" >0.025%</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row2_col7" class="data row2 col7" >0.027%</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row2_col8" class="data row2 col8" >0.032%</td>
#             </tr>
#             <tr>
#                                 <th id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1level1_row3" class="row_heading level1 row3" >Deaths</th>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row3_col0" class="data row3 col0" >23</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row3_col1" class="data row3 col1" ></td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row3_col2" class="data row3 col2" >4.078%</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row3_col3" class="data row3 col3" >1</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row3_col4" class="data row3 col4" >1</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row3_col5" class="data row3 col5" >1</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row3_col6" class="data row3 col6" ></td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row3_col7" class="data row3 col7" ></td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row3_col8" class="data row3 col8" ></td>
#             </tr>
#             <tr>
#                         <th id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1level0_row4" class="row_heading level0 row4" rowspan=2>San Marino</th>
#                         <th id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1level1_row4" class="row_heading level1 row4" >Cases</th>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row4_col0" class="data row4 col0" >308</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row4_col1" class="data row4 col1" >0.912%</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row4_col2" class="data row4 col2" ></td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row4_col3" class="data row4 col3" >29</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row4_col4" class="data row4 col4" >14</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row4_col5" class="data row4 col5" >10</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row4_col6" class="data row4 col6" >0.086%</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row4_col7" class="data row4 col7" >0.041%</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row4_col8" class="data row4 col8" >0.030%</td>
#             </tr>
#             <tr>
#                                 <th id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1level1_row5" class="row_heading level1 row5" >Deaths</th>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row5_col0" class="data row5 col0" >34</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row5_col1" class="data row5 col1" ></td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row5_col2" class="data row5 col2" >11.039%</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row5_col3" class="data row5 col3" >0</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row5_col4" class="data row5 col4" >0</td>
#                         <td id="T_38d84b46_7b00_11ea_8235_f7ca3c36ddf1row5_col5" class="data row5 col5" >1</td>
#                         <td id="T

# %% [markdown]
# ### Amount of cases, deaths
#
# These plots show the amount of cases and deaths over time.
#
# Do note that these numbers are reported by the countries, meaning they are accurate for as much as each country is testing their population. Though the confirmed cases will always be one or two weeks behind the actual numbers. As for the confirmed deaths, again countries can differ. Where, for example Belgium counts every death in the country due to COVID-19, Poland on the other hand only counts confirmed cases that died in the hospitals. <br>
# Always keep these things in mind when looking at any COVID-19 data.

# %%
mt.plot_spread('cases', '3days', countries, days=amount_days)
mt.plot_spread('cases', 'total', countries, days=amount_days)

# %% [markdown]
# Since all of these trends are expronential, it is interesting to look at the on a logarithmic scale.This is mainly used to compare their exponential trends, represented by the angle of the line towards the x-axis. For this reason we will translate them over the x-axis in a way that each country starts from the point they had their first 100 cases, or 10 deaths. This makes them line up neatly to compare their angles.

# %%
mt.plot_spread('cases', '3days', countries, scale='log')
mt.plot_spread('cases', 'total', countries, scale='log')

# %% [markdown]
# ### Incidence and Prevalence
#
# Since incidence and prevalence are relative to the population size, we can add the global information as a reference, mainly in the plot that are on the logarithmic scale, without messing up the scale of our plots.

# %%
countries.append('Global')

mt.plot_spread('incidence', '3days', countries, days=amount_days)
mt.plot_spread('incidence', '3days', countries, scale='log')

# %% [markdown]
# ### Mortality

# %%
mt.plot_mortality(countries)

# %% [markdown]
# ### Trends
#
# Show the growth rate compared to the total amount of cases, both relative to the population size.<br>
# Considering time is respresented by how the countries move on the graph, an animated version of this graph, showing the progression over time, will also be saved in Dynamic-Trends/.

# %%
mt.plot_trends_dynamically('highest_impact', countries)
# Out:
# No handles with labels found to put in legend.
