# %% [markdown]
# # Countries with the highest impact

# %%
import my_tools as mt

amount_days = 6 * 7
impacted_countries = mt.find_crit('impacted')
print(impacted_countries)
# Out:
# ['Andorra', 'Guernsey', 'Luxembourg', 'Iceland', 'Gibraltar', 'Spain', 'San Marino', 'Holy See']

# %%
mt.plot_spread('cases', '3days', impacted_countries, days=amount_days)
mt.plot_spread('cases', '3days', impacted_countries, scale='log')

# %%
mt.plot_spread('cases', 'total', impacted_countries, days=amount_days)
mt.plot_spread('cases', 'total', impacted_countries, scale='log')

# %%
impacted_countries.append('Global')

mt.plot_spread('incidence', '3days', impacted_countries, days=amount_days)
mt.plot_spread('incidence', '3days', impacted_countries, scale='log')

# %%
mt.plot_trends_dynamically('highest_impact', impacted_countries)
# Out:
# No handles with labels found to put in legend.

# %%
mt.show_table(impacted_countries)
# Out:
# <style  type="text/css" >
# </style><table id="T_18ca8142_78e5_11ea_882c_d96dcfc6ff62" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Today</th>        <th class="col_heading level0 col1" >3 day av</th>        <th class="col_heading level0 col2" >Weekly av</th>        <th class="col_heading level0 col3" >Incidence today</th>        <th class="col_heading level0 col4" >Incidence 3day av</th>        <th class="col_heading level0 col5" >Incidence weekly av</th>        <th class="col_heading level0 col6" >Total</th>        <th class="col_heading level0 col7" >Prevalence</th>        <th class="col_heading level0 col8" >Mortality</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_18ca8142_78e5_11ea_882c_d96dcfc6ff62level0_row0" class="row_heading level0 row0" rowspan=2>Andorra</th>
# ...
