# %% [markdown]
# ## Active countries
#
# This worksheet is part of a project to analyse and visualise data on the COVID-19 outbreak and will be run once a day.<br>
# It shows the data from a list of countries made by taking the intersection of the 10 countries with the most new cases and the 10 countries with the most new deaths. Both over the last week.
#
# To view this page in a bigger format, please right-click [here](https://github.com/simon-verheyen/Portfolio/tree/master/COVID-data) and open in a new tab.

# %%
import my_tools as mt

amount_days = 6 * 7
countries = mt.find_crit('active')
# Out:
# Latest update at 2020-04-11
# Latest data point at 2020-04-10

# %% [markdown]
# ### Table
#
# This table holds the latest information on each of the countries.
#
# - Incidence = New cases / Population
# - Prevalence = Total cases / Population

# %%
mt.show_table(countries)
# Out:
# <style  type="text/css" >
# </style><table id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493e" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total</th>        <th class="col_heading level0 col1" >Prevalence</th>        <th class="col_heading level0 col2" >Mortality</th>        <th class="col_heading level0 col3" >Today</th>        <th class="col_heading level0 col4" >3 days av</th>        <th class="col_heading level0 col5" >Weekly av</th>        <th class="col_heading level0 col6" >Incidence today</th>        <th class="col_heading level0 col7" >Incidence 3 days av</th>        <th class="col_heading level0 col8" >Incidence weekly av</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493elevel0_row0" class="row_heading level0 row0" rowspan=2>Global</th>
#                         <th id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493elevel1_row0" class="row_heading level1 row0" >Cases</th>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow0_col0" class="data row0 col0" >1563857</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow0_col1" class="data row0 col1" >0.021%</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow0_col2" class="data row0 col2" ></td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow0_col3" class="data row0 col3" >87039</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow0_col4" class="data row0 col4" >82290</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow0_col5" class="data row0 col5" >79702</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow0_col6" class="data row0 col6" >0.001%</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow0_col7" class="data row0 col7" >0.001%</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow0_col8" class="data row0 col8" >0.001%</td>
#             </tr>
#             <tr>
#                                 <th id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493elevel1_row1" class="row_heading level1 row1" >Deaths</th>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow1_col0" class="data row1 col0" >95044</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow1_col1" class="data row1 col1" ></td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow1_col2" class="data row1 col2" >6.078%</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow1_col3" class="data row1 col3" >7228</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow1_col4" class="data row1 col4" >6993</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow1_col5" class="data row1 col5" >6210</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow1_col6" class="data row1 col6" ></td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow1_col7" class="data row1 col7" ></td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow1_col8" class="data row1 col8" ></td>
#             </tr>
#             <tr>
#                         <th id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493elevel0_row2" class="row_heading level0 row2" rowspan=2>United States of America</th>
#                         <th id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493elevel1_row2" class="row_heading level1 row2" >Cases</th>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow2_col0" class="data row2 col0" >466033</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow2_col1" class="data row2 col1" >0.142%</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow2_col2" class="data row2 col2" ></td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow2_col3" class="data row2 col3" >33901</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow2_col4" class="data row2 col4" >32612</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow2_col5" class="data row2 col5" >31499</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow2_col6" class="data row2 col6" >0.010%</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow2_col7" class="data row2 col7" >0.010%</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow2_col8" class="data row2 col8" >0.010%</td>
#             </tr>
#             <tr>
#                                 <th id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493elevel1_row3" class="row_heading level1 row3" >Deaths</th>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow3_col0" class="data row3 col0" >16690</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow3_col1" class="data row3 col1" ></td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow3_col2" class="data row3 col2" >3.581%</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow3_col3" class="data row3 col3" >1873</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow3_col4" class="data row3 col4" >1900</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow3_col5" class="data row3 col5" >1519</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow3_col6" class="data row3 col6" ></td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow3_col7" class="data row3 col7" ></td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow3_col8" class="data row3 col8" ></td>
#             </tr>
#             <tr>
#                         <th id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493elevel0_row4" class="row_heading level0 row4" rowspan=2>Spain</th>
#                         <th id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493elevel1_row4" class="row_heading level1 row4" >Cases</th>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow4_col0" class="data row4 col0" >152446</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow4_col1" class="data row4 col1" >0.326%</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow4_col2" class="data row4 col2" ></td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow4_col3" class="data row4 col3" >5756</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow4_col4" class="data row4 col4" >5804</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow4_col5" class="data row4 col5" >6029</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow4_col6" class="data row4 col6" >0.012%</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow4_col7" class="data row4 col7" >0.012%</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow4_col8" class="data row4 col8" >0.013%</td>
#             </tr>
#             <tr>
#                                 <th id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493elevel1_row5" class="row_heading level1 row5" >Deaths</th>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow5_col0" class="data row5 col0" >15238</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow5_col1" class="data row5 col1" ></td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow5_col2" class="data row5 col2" >9.996%</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow5_col3" class="data row5 col3" >683</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow5_col4" class="data row5 col4" >727</td>
#                         <td id="T_89c1dbe4_7bd7_11ea_b665_657ba1bc493erow5_col5" class="data r

# %% [markdown]
# ### Amount of cases, deaths
#
# These plots show the amount of cases and deaths over time.
#
# Do note that these numbers are reported by the countries, meaning they are accurate for as much as each country is testing their population. Though the confirmed cases will always be one or two weeks behind the actual numbers. As for the confirmed deaths, again countries can differ. Where, for example Belgium counts every death in the country due to COVID-19, Poland on the other hand only counts confirmed cases that died in the hospitals. <br>
# Always keep these things in mind when looking at any COVID-19 data.

# %%
mt.plot_spread('cases', '3days', countries, days=amount_days)
mt.plot_spread('cases', 'total', countries, days=amount_days)

# %% [markdown]
# Since all of these trends are expronential, it is interesting to look at the on a logarithmic scale.This is mainly used to compare their exponential trends, represented by the angle of the line towards the x-axis. For this reason we will translate them over the x-axis in a way that each country starts from the point they had their first 100 cases, or 10 deaths. This makes them line up neatly to compare their angles.

# %%
mt.plot_spread('cases', '3days', countries, scale='log')
mt.plot_spread('cases', 'total', countries, scale='log')

# %% [markdown]
# ### Incidence and Prevalence
#
# Since incidence and prevalence are relative to the population size, we can add the global information as a reference, mainly in the plot that are on the logarithmic scale, without messing up the scale of our plots.

# %%
countries.append('Global')

mt.plot_spread('incidence', '3days', countries, days=amount_days)
mt.plot_spread('incidence', '3days', countries, scale='log')

# %% [markdown]
# ### Mortality

# %%
mt.plot_mortality(countries)

# %% [markdown]
# ### Trends
#
# Show the growth rate compared to the total amount of cases, both relative to the population size.<br>
# Considering time is respresented by how the countries move on the graph, an animated version of this graph, showing the progression over time, will also be saved in Dynamic-Trends/.

# %%
mt.plot_trends_dynamically('most_new_cases', countries)
# Out:
# No handles with labels found to put in legend.
