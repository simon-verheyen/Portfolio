# %% [markdown]
# ## Active countries

# %%
import my_tools as mt

active_countries = mt.find_crit('active')
print(active_countries)

amount_days = 15
# Out:
# ['United States of America', 'Spain', 'Germany', 'Italy', 'France', 'United Kingdom', 'Iran', 'Belgium']

# %%
mt.plot_spread('cases', '3days', active_countries, days=amount_days)
mt.plot_spread('cases', '3days', active_countries, scale='log')

# %%
mt.plot_spread('cases', 'total', active_countries, days=amount_days)
mt.plot_spread('cases', 'total', active_countries, scale='log')

# %%
active_countries.append('Global')

mt.plot_spread('incidence', '3days', active_countries, days=amount_days)
mt.plot_spread('incidence', '3days', active_countries, scale='log')

# %%
mt.plot_trends_dynamically('most_new_cases', active_countries)
# Out:
# No handles with labels found to put in legend.

# %%
mt.show_table(active_countries)
# Out:
# <style  type="text/css" >
# </style><table id="T_1a640406_78e5_11ea_b302_d3dd3819c218" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Today</th>        <th class="col_heading level0 col1" >3 day av</th>        <th class="col_heading level0 col2" >Weekly av</th>        <th class="col_heading level0 col3" >Incidence today</th>        <th class="col_heading level0 col4" >Incidence 3day av</th>        <th class="col_heading level0 col5" >Incidence weekly av</th>        <th class="col_heading level0 col6" >Total</th>        <th class="col_heading level0 col7" >Prevalence</th>        <th class="col_heading level0 col8" >Mortality</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1a640406_78e5_11ea_b302_d3dd3819c218level0_row0" class="row_heading level0 row0" rowspan=2>United States of America</th>
# ...
