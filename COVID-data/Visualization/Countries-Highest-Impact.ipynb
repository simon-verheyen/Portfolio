# %% [markdown]
# # Countries with the highest impact

# %%
import my_tools as mt

amount_days = 6 * 7
impacted_countries = mt.find_crit('impacted')
print(impacted_countries)
# Out:
# ['Andorra', 'Guernsey', 'Luxembourg', 'Iceland', 'Gibraltar', 'Spain', 'San Marino', 'Holy See']

# %%
mt.plot_spread('cases', '3days', impacted_countries, days=amount_days)
mt.plot_spread('cases', '3days', impacted_countries, scale='log', days=amount_days)

# %%
mt.plot_spread('cases', 'total', impacted_countries)
mt.plot_spread('cases', 'total', impacted_countries, scale='log')

# %%
impacted_countries.append('Global')

mt.plot_spread('incidence', '3days', impacted_countries)
mt.plot_spread('incidence', '3days', impacted_countries, scale='log')

# %%
mt.plot_trends_dynamically('impacted_countries', impacted_countries)
# Out:
# No handles with labels found to put in legend.

# %%
mt.show_table(impacted_countries)
# Out:
# <style  type="text/css" >
# </style><table id="T_63222c8a_78e1_11ea_806a_0f37a073a0ce" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Today</th>        <th class="col_heading level0 col1" >3 day av</th>        <th class="col_heading level0 col2" >Weekly av</th>        <th class="col_heading level0 col3" >Incidence today</th>        <th class="col_heading level0 col4" >Incidence 3day av</th>        <th class="col_heading level0 col5" >Incidence weekly av</th>        <th class="col_heading level0 col6" >Total</th>        <th class="col_heading level0 col7" >Prevalence</th>        <th class="col_heading level0 col8" >Mortality</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_63222c8a_78e1_11ea_806a_0f37a073a0celevel0_row0" class="row_heading level0 row0" rowspan=2>Andorra</th>
#                         <th id="T_63222c8a_78e1_11ea_806a_0f37a073a0celevel1_row0" class="row_heading level1 row0" >Cases</th>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow0_col0" class="data row0 col0" >35</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow0_col1" class="data row0 col1" >23.8571</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow0_col2" class="data row0 col2" >23.8571</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow0_col3" class="data row0 col3" >0.045%</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow0_col4" class="data row0 col4" >0.045%</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow0_col5" class="data row0 col5" >0.031%</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow0_col6" class="data row0 col6" >501</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow0_col7" class="data row0 col7" >0.651%</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow0_col8" class="data row0 col8" ></td>
#             </tr>
#             <tr>
#                                 <th id="T_63222c8a_78e1_11ea_806a_0f37a073a0celevel1_row1" class="row_heading level1 row1" >Deaths</th>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow1_col0" class="data row1 col0" >1</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow1_col1" class="data row1 col1" >1.71429</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow1_col2" class="data row1 col2" >1.71429</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow1_col3" class="data row1 col3" ></td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow1_col4" class="data row1 col4" ></td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow1_col5" class="data row1 col5" ></td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow1_col6" class="data row1 col6" >18</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow1_col7" class="data row1 col7" ></td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow1_col8" class="data row1 col8" >3.593%</td>
#             </tr>
#             <tr>
#                         <th id="T_63222c8a_78e1_11ea_806a_0f37a073a0celevel0_row2" class="row_heading level0 row2" rowspan=2>Guernsey</th>
#                         <th id="T_63222c8a_78e1_11ea_806a_0f37a073a0celevel1_row2" class="row_heading level1 row2" >Cases</th>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow2_col0" class="data row2 col0" >18</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow2_col1" class="data row2 col1" >15.5714</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow2_col2" class="data row2 col2" >15.5714</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow2_col3" class="data row2 col3" >0.029%</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow2_col4" class="data row2 col4" >0.029%</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow2_col5" class="data row2 col5" >0.025%</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow2_col6" class="data row2 col6" >154</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow2_col7" class="data row2 col7" >0.244%</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow2_col8" class="data row2 col8" ></td>
#             </tr>
#             <tr>
#                                 <th id="T_63222c8a_78e1_11ea_806a_0f37a073a0celevel1_row3" class="row_heading level1 row3" >Deaths</th>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow3_col0" class="data row3 col0" >1</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow3_col1" class="data row3 col1" >0.428571</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow3_col2" class="data row3 col2" >0.428571</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow3_col3" class="data row3 col3" ></td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow3_col4" class="data row3 col4" ></td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow3_col5" class="data row3 col5" ></td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow3_col6" class="data row3 col6" >3</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow3_col7" class="data row3 col7" ></td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow3_col8" class="data row3 col8" >1.948%</td>
#             </tr>
#             <tr>
#                         <th id="T_63222c8a_78e1_11ea_806a_0f37a073a0celevel0_row4" class="row_heading level0 row4" rowspan=2>Luxembourg</th>
#                         <th id="T_63222c8a_78e1_11ea_806a_0f37a073a0celevel1_row4" class="row_heading level1 row4" >Cases</th>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow4_col0" class="data row4 col0" >75</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow4_col1" class="data row4 col1" >122</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow4_col2" class="data row4 col2" >122</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow4_col3" class="data row4 col3" >0.012%</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow4_col4" class="data row4 col4" >0.012%</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow4_col5" class="data row4 col5" >0.020%</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow4_col6" class="data row4 col6" >2804</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow4_col7" class="data row4 col7" >0.461%</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow4_col8" class="data row4 col8" ></td>
#             </tr>
#             <tr>
#                                 <th id="T_63222c8a_78e1_11ea_806a_0f37a073a0celevel1_row5" class="row_heading level1 row5" >Deaths</th>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow5_col0" class="data row5 col0" >5</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow5_col1" class="data row5 col1" >2.14286</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow5_col2" class="data row5 col2" >2.14286</td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow5_col3" class="data row5 col3" ></td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow5_col4" class="data row5 col4" ></td>
#                         <td id="T_63222c8a_78e1_11ea_806a_0f37a073a0cerow5_col5" class="data row5 col5" ></td>
