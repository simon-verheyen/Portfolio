# %%
import my_tools as mt

country_list = ['China', 'South Korea', 'United States of America', 'Belgium', 'United Kingdom', 'Italy', 'Spain']

# %% [markdown]
# - prevalence = total cases / population
# - incidence = new cases / popultaion

# %%
mt.plot_global()

# %%
mt.plot_spread('daily', country_list)
mt.plot_spread('3days', country_list)
mt.plot_spread('weekly', country_list)

# %%
mt.plot_spread('daily', country_list, scale='log')
mt.plot_spread('3days', country_list, scale='log')
mt.plot_spread('weekly', country_list, scale='log')

# %%
mt.plot_spread('total', country_list)
mt.plot_spread('total', country_list, scale='log')

# %%
mt.plot_spread('incidence_daily', country_list)
mt.plot_spread('incidence_3days', country_list)
mt.plot_spread('incidence_weekly', country_list)

# %%
mt.plot_spread('incidence_daily', country_list, scale='log')
mt.plot_spread('incidence_3days', country_list, scale='log')
mt.plot_spread('incidence_weekly', country_list, scale='log')

# %%
mt.plot_trends(country_list, subject='spread', per='3days')
mt.plot_trends(country_list, subject='impact', per='3days')
# Out:
# /home/simon/Portfolio/COVID-data/Visualization/my_tools.py:221: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   df_global_trends = df_global_trends.loc[eval('dates_' + per)]

# %%
mt.plot_trends(country_list, subject='spread', per='weekly')
mt.plot_trends(country_list, subject='impact', per='weekly')
