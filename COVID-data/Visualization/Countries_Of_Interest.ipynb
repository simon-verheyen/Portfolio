# %% [markdown]
# # Countries of interest
#
# This worksheet is part of a project to analyse and visualise data on the COVID-19 outbreak and will be run once a day.<br>
# It shows data from a selection of countries deemed interesting through personal relations, as well as for interesting reference.

# %%
import my_tools as mt

countries = ['China', 'France', 'Italy', 'United States of America', 'Spain', 'United Kingdom', 'Belgium', 'Iran', 'Ukraine', 'South Korea']
countries.sort()

# %% [markdown]
# ### Table
#
# This table holds the latest information on each of the countries.
#
# - Incidence = New cases / Population
# - Prevalence = Total cases / Population

# %%
mt.show_table(countries)
# Out:
# <style  type="text/css" >
# </style><table id="T_21b78fc8_79c3_11ea_b915_9994be10c34c" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total</th>        <th class="col_heading level0 col1" >Prevalence</th>        <th class="col_heading level0 col2" >Mortality</th>        <th class="col_heading level0 col3" >Today</th>        <th class="col_heading level0 col4" >3 days av</th>        <th class="col_heading level0 col5" >Weekly av</th>        <th class="col_heading level0 col6" >Incidence today</th>        <th class="col_heading level0 col7" >Incidence 3 days av</th>        <th class="col_heading level0 col8" >Incidence weekly av</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_21b78fc8_79c3_11ea_b915_9994be10c34clevel0_row0" class="row_heading level0 row0" rowspan=2>Global</th>
#                         <th id="T_21b78fc8_79c3_11ea_b915_9994be10c34clevel1_row0" class="row_heading level1 row0" >Cases</th>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow0_col0" class="data row0 col0" >1316988</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow0_col1" class="data row0 col1" >0.018%</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow0_col2" class="data row0 col2" ></td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow0_col3" class="data row0 col3" >71392</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow0_col4" class="data row0 col4" >76445</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow0_col5" class="data row0 col5" >77027</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow0_col6" class="data row0 col6" >0.001%</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow0_col7" class="data row0 col7" >0.001%</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow0_col8" class="data row0 col8" >0.001%</td>
#             </tr>
#             <tr>
#                                 <th id="T_21b78fc8_79c3_11ea_b915_9994be10c34clevel1_row1" class="row_heading level1 row1" >Deaths</th>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow1_col0" class="data row1 col0" >74066</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow1_col1" class="data row1 col1" ></td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow1_col2" class="data row1 col2" >5.624%</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow1_col3" class="data row1 col3" >5137</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow1_col4" class="data row1 col4" >5302</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow1_col5" class="data row1 col5" >5256</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow1_col6" class="data row1 col6" ></td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow1_col7" class="data row1 col7" ></td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow1_col8" class="data row1 col8" ></td>
#             </tr>
#             <tr>
#                         <th id="T_21b78fc8_79c3_11ea_b915_9994be10c34clevel0_row2" class="row_heading level0 row2" rowspan=2>Belgium</th>
#                         <th id="T_21b78fc8_79c3_11ea_b915_9994be10c34clevel1_row2" class="row_heading level1 row2" >Cases</th>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow2_col0" class="data row2 col0" >20814</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow2_col1" class="data row2 col1" >0.182%</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow2_col2" class="data row2 col2" ></td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow2_col3" class="data row2 col3" >1123</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow2_col4" class="data row2 col4" >1348</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow2_col5" class="data row2 col5" >1273</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow2_col6" class="data row2 col6" >0.010%</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow2_col7" class="data row2 col7" >0.012%</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow2_col8" class="data row2 col8" >0.011%</td>
#             </tr>
#             <tr>
#                                 <th id="T_21b78fc8_79c3_11ea_b915_9994be10c34clevel1_row3" class="row_heading level1 row3" >Deaths</th>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow3_col0" class="data row3 col0" >1632</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow3_col1" class="data row3 col1" ></td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow3_col2" class="data row3 col2" >7.841%</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow3_col3" class="data row3 col3" >185</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow3_col4" class="data row3 col4" >163</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow3_col5" class="data row3 col5" >159</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow3_col6" class="data row3 col6" ></td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow3_col7" class="data row3 col7" ></td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow3_col8" class="data row3 col8" ></td>
#             </tr>
#             <tr>
#                         <th id="T_21b78fc8_79c3_11ea_b915_9994be10c34clevel0_row4" class="row_heading level0 row4" rowspan=2>China</th>
#                         <th id="T_21b78fc8_79c3_11ea_b915_9994be10c34clevel1_row4" class="row_heading level1 row4" >Cases</th>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow4_col0" class="data row4 col0" >82698</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow4_col1" class="data row4 col1" >0.006%</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow4_col2" class="data row4 col2" ></td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow4_col3" class="data row4 col3" >56</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow4_col4" class="data row4 col4" >57</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow4_col5" class="data row4 col5" >65</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow4_col6" class="data row4 col6" >0.000%</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow4_col7" class="data row4 col7" >0.000%</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow4_col8" class="data row4 col8" >0.000%</td>
#             </tr>
#             <tr>
#                                 <th id="T_21b78fc8_79c3_11ea_b915_9994be10c34clevel1_row5" class="row_heading level1 row5" >Deaths</th>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow5_col0" class="data row5 col0" >3335</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow5_col1" class="data row5 col1" ></td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow5_col2" class="data row5 col2" >4.033%</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow5_col3" class="data row5 col3" >0</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow5_col4" class="data row5 col4" >1</td>
#                         <td id="T_21b78fc8_79c3_11ea_b915_9994be10c34crow5_col5" class="data row5 col5" >3</td>

# %% [markdown]
# ### Amount of cases, deaths
#
# These plots show the amount of cases and deaths over time.

# %%
mt.plot_spread('cases', '3days', countries)
mt.plot_spread('cases', 'total', countries)

# %% [markdown]
# Since all of these trends are expronential, it is interesting to look at the on a logarithmic scale.This is mainly used to compare their exponential trends, represented by the angle of the line towards the x-axis. For this reason we will translate them over the x-axis in a way that each country starts from the point they had their first 100 cases, or 10 deaths. This makes them line up neatly to compare their angles.

# %%
mt.plot_spread('cases', '3days', countries, scale='log')
mt.plot_spread('cases', 'total', countries, scale='log')

# %% [markdown]
# ### Incidence and Prevalence
#
# Since incidence and prevalence are relative to the population size, we can add the global information as a reference, mainly in the plot that are on the logarithmic scale, without messing up the scale of our plots.

# %%
countries.append('Global')

mt.plot_spread('incidence', '3days', countries)
mt.plot_spread('incidence', '3days', countries, scale='log')

# %% [markdown]
# ### Trends
#
# Show the growth rate compared to the total amount of cases, both relative to the population size.<br>
# Considering time is respresented by how the countries move on the graph, an animated version of this graph, showing the progression over time, will also be saved in Dynamic-Trends/.

# %%
mt.plot_trends_dynamically('countries_of_interest', countries)
# Out:
# No handles with labels found to put in legend.
