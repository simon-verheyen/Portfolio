# %% [markdown]
# # Showcase of all plots
#
# This worksheet holds, for a certain set of countries, nearly all plots that can be generated with the data- and toolsets.

# %%
import my_tools as mt

country_list = ['China', 'South Korea', 'United States of America', 'Belgium', 'United Kingdom', 'Italy', 'Spain']

# %% [markdown]
# 3days: The average value over 3 days time<br>
# Weekly: The average value over a week
#
#
# - Prevalence = Total cases / Population
# - Incidence =  New cases / Popultaion
# - Mortality = Total cases / Total deaths

# %%
mt.plot_spread('cases', 'daily', countries=country_list)
mt.plot_spread('cases', '3days', countries=country_list)
mt.plot_spread('cases', 'weekly', countries=country_list)

# %%
mt.plot_spread('cases', 'daily', country_list, scale='log')
mt.plot_spread('cases', '3days', country_list, scale='log')
mt.plot_spread('cases', 'weekly', country_list, scale='log')

# %%
mt.plot_spread('cases', 'total', countries=country_list)
mt.plot_spread('cases', 'total', country_list, scale='log')

# %%
mt.plot_spread('incidence', 'daily', countries=country_list)
mt.plot_spread('incidence', '3days', countries=country_list)
mt.plot_spread('incidence', 'weekly', countries=country_list)

# %%
mt.plot_spread('incidence', 'daily', country_list, scale='log')
mt.plot_spread('incidence', '3days', country_list, scale='log')
mt.plot_spread('incidence', 'weekly', country_list, scale='log')

# %%
mt.plot_trends(country_list, subj='spread', per='3days')
mt.plot_trends(country_list, subj='impact', per='3days')

# %%
mt.plot_trends(country_list, subj='spread', per='weekly')
mt.plot_trends(country_list, subj='impact', per='weekly')

# %%
mt.plot_trends_dynamically('test', country_list)
# Out:
# No handles with labels found to put in legend.

# %%
mt.show_table(country_list)
# Out:
# <style  type="text/css" >
# </style><table id="T_054e6736_79c2_11ea_badc_49f3bb7dda53" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total</th>        <th class="col_heading level0 col1" >Prevalence</th>        <th class="col_heading level0 col2" >Mortality</th>        <th class="col_heading level0 col3" >Today</th>        <th class="col_heading level0 col4" >3 days av</th>        <th class="col_heading level0 col5" >Weekly av</th>        <th class="col_heading level0 col6" >Incidence today</th>        <th class="col_heading level0 col7" >Incidence 3 days av</th>        <th class="col_heading level0 col8" >Incidence weekly av</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_054e6736_79c2_11ea_badc_49f3bb7dda53level0_row0" class="row_heading level0 row0" rowspan=2>Global</th>
#                         <th id="T_054e6736_79c2_11ea_badc_49f3bb7dda53level1_row0" class="row_heading level1 row0" >Cases</th>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row0_col0" class="data row0 col0" >1316988</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row0_col1" class="data row0 col1" >0.018%</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row0_col2" class="data row0 col2" ></td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row0_col3" class="data row0 col3" >71392</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row0_col4" class="data row0 col4" >76445</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row0_col5" class="data row0 col5" >77027</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row0_col6" class="data row0 col6" >0.001%</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row0_col7" class="data row0 col7" >0.001%</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row0_col8" class="data row0 col8" >0.001%</td>
#             </tr>
#             <tr>
#                                 <th id="T_054e6736_79c2_11ea_badc_49f3bb7dda53level1_row1" class="row_heading level1 row1" >Deaths</th>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row1_col0" class="data row1 col0" >74066</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row1_col1" class="data row1 col1" ></td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row1_col2" class="data row1 col2" >5.624%</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row1_col3" class="data row1 col3" >5137</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row1_col4" class="data row1 col4" >5302</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row1_col5" class="data row1 col5" >5256</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row1_col6" class="data row1 col6" ></td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row1_col7" class="data row1 col7" ></td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row1_col8" class="data row1 col8" ></td>
#             </tr>
#             <tr>
#                         <th id="T_054e6736_79c2_11ea_badc_49f3bb7dda53level0_row2" class="row_heading level0 row2" rowspan=2>China</th>
#                         <th id="T_054e6736_79c2_11ea_badc_49f3bb7dda53level1_row2" class="row_heading level1 row2" >Cases</th>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row2_col0" class="data row2 col0" >82698</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row2_col1" class="data row2 col1" >0.006%</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row2_col2" class="data row2 col2" ></td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row2_col3" class="data row2 col3" >56</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row2_col4" class="data row2 col4" >57</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row2_col5" class="data row2 col5" >65</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row2_col6" class="data row2 col6" >0.000%</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row2_col7" class="data row2 col7" >0.000%</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row2_col8" class="data row2 col8" >0.000%</td>
#             </tr>
#             <tr>
#                                 <th id="T_054e6736_79c2_11ea_badc_49f3bb7dda53level1_row3" class="row_heading level1 row3" >Deaths</th>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row3_col0" class="data row3 col0" >3335</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row3_col1" class="data row3 col1" ></td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row3_col2" class="data row3 col2" >4.033%</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row3_col3" class="data row3 col3" >0</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row3_col4" class="data row3 col4" >1</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row3_col5" class="data row3 col5" >3</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row3_col6" class="data row3 col6" ></td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row3_col7" class="data row3 col7" ></td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row3_col8" class="data row3 col8" ></td>
#             </tr>
#             <tr>
#                         <th id="T_054e6736_79c2_11ea_badc_49f3bb7dda53level0_row4" class="row_heading level0 row4" rowspan=2>South Korea</th>
#                         <th id="T_054e6736_79c2_11ea_badc_49f3bb7dda53level1_row4" class="row_heading level1 row4" >Cases</th>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row4_col0" class="data row4 col0" >10331</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row4_col1" class="data row4 col1" >0.020%</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row4_col2" class="data row4 col2" ></td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row4_col3" class="data row4 col3" >47</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row4_col4" class="data row4 col4" >58</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row4_col5" class="data row4 col5" >77</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row4_col6" class="data row4 col6" >0.000%</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row4_col7" class="data row4 col7" >0.000%</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row4_col8" class="data row4 col8" >0.000%</td>
#             </tr>
#             <tr>
#                                 <th id="T_054e6736_79c2_11ea_badc_49f3bb7dda53level1_row5" class="row_heading level1 row5" >Deaths</th>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row5_col0" class="data row5 col0" >192</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row5_col1" class="data row5 col1" ></td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row5_col2" class="data row5 col2" >1.858%</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row5_col3" class="data row5 col3" >6</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row5_col4" class="data row5 col4" >5</td>
#                         <td id="T_054e6736_79c2_11ea_badc_49f3bb7dda53row5_col5" class="data row5 col5" >4</td>
#                         <td
