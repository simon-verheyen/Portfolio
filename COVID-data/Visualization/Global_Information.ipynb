# %% [markdown]
# # Global Infromation
#
# This worksheet is part of a project to analyse and visualise data on the COVID-19 outbreak and will be run once a day.<br>
# It worksheet shows the global data and the data on all the continents.<br>
# At the bottom of this worksheet is a table containing the new data on all the countries that we have data on, ordered alphabetically.
#
# To view this page in a bigger format, please right-click [here](https://github.com/simon-verheyen/Portfolio/tree/master/COVID-data) and open in a new tab.

# %%
import my_tools as mt

continents = ['Global', 'Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America']
# Out:
# Latest update at 2020-04-11
# Latest data point at 2020-04-10

# %% [markdown]
# ### Table
#
# This table holds the latest information on each of the countries.
#
# - Incidence = New cases / Population
# - Prevalence = Total cases / Population

# %%
mt.show_table(continents)
# Out:
# <style  type="text/css" >
# </style><table id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total</th>        <th class="col_heading level0 col1" >Prevalence</th>        <th class="col_heading level0 col2" >Mortality</th>        <th class="col_heading level0 col3" >Today</th>        <th class="col_heading level0 col4" >3 days av</th>        <th class="col_heading level0 col5" >Weekly av</th>        <th class="col_heading level0 col6" >Incidence today</th>        <th class="col_heading level0 col7" >Incidence 3 days av</th>        <th class="col_heading level0 col8" >Incidence weekly av</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58level0_row0" class="row_heading level0 row0" rowspan=2>Global</th>
#                         <th id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58level1_row0" class="row_heading level1 row0" >Cases</th>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row0_col0" class="data row0 col0" >1563857</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row0_col1" class="data row0 col1" >0.021%</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row0_col2" class="data row0 col2" ></td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row0_col3" class="data row0 col3" >87039</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row0_col4" class="data row0 col4" >82290</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row0_col5" class="data row0 col5" >79702</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row0_col6" class="data row0 col6" >0.001%</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row0_col7" class="data row0 col7" >0.001%</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row0_col8" class="data row0 col8" >0.001%</td>
#             </tr>
#             <tr>
#                                 <th id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58level1_row1" class="row_heading level1 row1" >Deaths</th>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row1_col0" class="data row1 col0" >95044</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row1_col1" class="data row1 col1" ></td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row1_col2" class="data row1 col2" >6.078%</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row1_col3" class="data row1 col3" >7228</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row1_col4" class="data row1 col4" >6993</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row1_col5" class="data row1 col5" >6210</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row1_col6" class="data row1 col6" ></td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row1_col7" class="data row1 col7" ></td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row1_col8" class="data row1 col8" ></td>
#             </tr>
#             <tr>
#                         <th id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58level0_row2" class="row_heading level0 row2" rowspan=2>Africa</th>
#                         <th id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58level1_row2" class="row_heading level1 row2" >Cases</th>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row2_col0" class="data row2 col0" >12280</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row2_col1" class="data row2 col1" >0.001%</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row2_col2" class="data row2 col2" ></td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row2_col3" class="data row2 col3" >834</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row2_col4" class="data row2 col4" >826</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row2_col5" class="data row2 col5" >790</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row2_col6" class="data row2 col6" >0.000%</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row2_col7" class="data row2 col7" >0.000%</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row2_col8" class="data row2 col8" >0.000%</td>
#             </tr>
#             <tr>
#                                 <th id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58level1_row3" class="row_heading level1 row3" >Deaths</th>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row3_col0" class="data row3 col0" >630</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row3_col1" class="data row3 col1" ></td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row3_col2" class="data row3 col2" >5.130%</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row3_col3" class="data row3 col3" >57</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row3_col4" class="data row3 col4" >51</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row3_col5" class="data row3 col5" >54</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row3_col6" class="data row3 col6" ></td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row3_col7" class="data row3 col7" ></td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row3_col8" class="data row3 col8" ></td>
#             </tr>
#             <tr>
#                         <th id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58level0_row4" class="row_heading level0 row4" rowspan=2>Asia</th>
#                         <th id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58level1_row4" class="row_heading level1 row4" >Cases</th>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row4_col0" class="data row4 col0" >261364</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row4_col1" class="data row4 col1" >0.006%</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row4_col2" class="data row4 col2" ></td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row4_col3" class="data row4 col3" >10024</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row4_col4" class="data row4 col4" >9625</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row4_col5" class="data row4 col5" >9498</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row4_col6" class="data row4 col6" >0.000%</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row4_col7" class="data row4 col7" >0.000%</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row4_col8" class="data row4 col8" >0.000%</td>
#             </tr>
#             <tr>
#                                 <th id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58level1_row5" class="row_heading level1 row5" >Deaths</th>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row5_col0" class="data row5 col0" >9839</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row5_col1" class="data row5 col1" ></td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row5_col2" class="data row5 col2" >3.764%</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row5_col3" class="data row5 col3" >348</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row5_col4" class="data row5 col4" >316</td>
#                         <td id="T_86839aa8_7bd7_11ea_91b8_f56f98e4af58row5_col5" class="data row5 col5" >306</td>

# %% [markdown]
# ### Amount of cases, deaths
#
# These plots show the amount of cases and deaths over time.
#
# Do note that these numbers are reported by the countries, meaning they are accurate for as much as each country is testing their population. Though the confirmed cases will always be one or two weeks behind the actual numbers. As for the confirmed deaths, again countries can differ. Where, for example Belgium counts every death in the country due to COVID-19, Poland on the other hand only counts confirmed cases that died in the hospitals. <br>
# Always keep these things in mind when looking at any COVID-19 data.

# %%
mt.plot_spread('cases', '3days', continents)
mt.plot_spread('cases', 'total', continents)

# %% [markdown]
# Since all of these trends are expronential, it is interesting to look at the on a logarithmic scale.This is mainly used to compare their exponential trends, represented by the angle of the line towards the x-axis. For this reason we will translate them over the x-axis in a way that each country starts from the point they had their first 100 cases, or 10 deaths. This makes them line up neatly to compare their angles.

# %%
mt.plot_spread('cases', '3days', continents, scale='log')
mt.plot_spread('cases', 'total', continents, scale='log')

# %% [markdown]
# ### Incidence and Prevalence
#
# Since incidence and prevalence are relative to the population size, we can add the global information as a reference, mainly in the plot that are on the logarithmic scale, without messing up the scale of our plots.

# %%
mt.plot_spread('incidence', '3days', continents)
mt.plot_spread('incidence', '3days', continents, scale='log')

# %% [markdown]
# ### Mortality

# %%
mt.plot_mortality(continents)

# %% [markdown]
# ### Trends
#
# Show the growth rate compared to the total amount of cases, both relative to the population size.<br>
# Considering time is respresented by how the countries move on the graph, an animated version of this graph, showing the progression over time, will also be saved in Dynamic-Trends/.

# %%
mt.plot_trends_dynamically('continents', continents)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### Table with all countries
#
# This table contains the new data on all the countries that we have data on.

# %%
mt.show_table()
# Out:
# <style  type="text/css" >
# </style><table id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Total</th>        <th class="col_heading level0 col1" >Prevalence</th>        <th class="col_heading level0 col2" >Mortality</th>        <th class="col_heading level0 col3" >Today</th>        <th class="col_heading level0 col4" >3 days av</th>        <th class="col_heading level0 col5" >Weekly av</th>        <th class="col_heading level0 col6" >Incidence today</th>        <th class="col_heading level0 col7" >Incidence 3 days av</th>        <th class="col_heading level0 col8" >Incidence weekly av</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58level0_row0" class="row_heading level0 row0" rowspan=2>Global</th>
#                         <th id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58level1_row0" class="row_heading level1 row0" >Cases</th>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row0_col0" class="data row0 col0" >1563857</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row0_col1" class="data row0 col1" >0.021%</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row0_col2" class="data row0 col2" ></td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row0_col3" class="data row0 col3" >87039</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row0_col4" class="data row0 col4" >82290</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row0_col5" class="data row0 col5" >79702</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row0_col6" class="data row0 col6" >0.001%</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row0_col7" class="data row0 col7" >0.001%</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row0_col8" class="data row0 col8" >0.001%</td>
#             </tr>
#             <tr>
#                                 <th id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58level1_row1" class="row_heading level1 row1" >Deaths</th>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row1_col0" class="data row1 col0" >95044</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row1_col1" class="data row1 col1" ></td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row1_col2" class="data row1 col2" >6.078%</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row1_col3" class="data row1 col3" >7228</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row1_col4" class="data row1 col4" >6993</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row1_col5" class="data row1 col5" >6210</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row1_col6" class="data row1 col6" ></td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row1_col7" class="data row1 col7" ></td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row1_col8" class="data row1 col8" ></td>
#             </tr>
#             <tr>
#                         <th id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58level0_row2" class="row_heading level0 row2" rowspan=2>Africa</th>
#                         <th id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58level1_row2" class="row_heading level1 row2" >Cases</th>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row2_col0" class="data row2 col0" >12280</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row2_col1" class="data row2 col1" >0.001%</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row2_col2" class="data row2 col2" ></td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row2_col3" class="data row2 col3" >834</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row2_col4" class="data row2 col4" >826</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row2_col5" class="data row2 col5" >790</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row2_col6" class="data row2 col6" >0.000%</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row2_col7" class="data row2 col7" >0.000%</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row2_col8" class="data row2 col8" >0.000%</td>
#             </tr>
#             <tr>
#                                 <th id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58level1_row3" class="row_heading level1 row3" >Deaths</th>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row3_col0" class="data row3 col0" >630</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row3_col1" class="data row3 col1" ></td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row3_col2" class="data row3 col2" >5.130%</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row3_col3" class="data row3 col3" >57</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row3_col4" class="data row3 col4" >51</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row3_col5" class="data row3 col5" >54</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row3_col6" class="data row3 col6" ></td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row3_col7" class="data row3 col7" ></td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row3_col8" class="data row3 col8" ></td>
#             </tr>
#             <tr>
#                         <th id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58level0_row4" class="row_heading level0 row4" rowspan=2>Asia</th>
#                         <th id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58level1_row4" class="row_heading level1 row4" >Cases</th>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row4_col0" class="data row4 col0" >261364</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row4_col1" class="data row4 col1" >0.006%</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row4_col2" class="data row4 col2" ></td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row4_col3" class="data row4 col3" >10024</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row4_col4" class="data row4 col4" >9625</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row4_col5" class="data row4 col5" >9498</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row4_col6" class="data row4 col6" >0.000%</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row4_col7" class="data row4 col7" >0.000%</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row4_col8" class="data row4 col8" >0.000%</td>
#             </tr>
#             <tr>
#                                 <th id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58level1_row5" class="row_heading level1 row5" >Deaths</th>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row5_col0" class="data row5 col0" >9839</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row5_col1" class="data row5 col1" ></td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row5_col2" class="data row5 col2" >3.764%</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row5_col3" class="data row5 col3" >348</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row5_col4" class="data row5 col4" >316</td>
#                         <td id="T_8c859c12_7bd7_11ea_91b8_f56f98e4af58row5_col5" class="data row5 col5" >306</td>
