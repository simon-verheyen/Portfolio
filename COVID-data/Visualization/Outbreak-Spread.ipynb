# %% [markdown]
# <a id="top"> </a>
#
# To view this on a full page, please right-click and 'open in new tab' [this link](#"top").<br/>
# Apologies that the internal hyperlinks don't work in github, this will be investigated in the future.
# # COVID-19 Outbreak Spread
# ---
#
# <a id="division_ID"> </a>
#
# This notebook is part of a toolset to analyse and visualise data on the COVID-19 outbreak and will be run once a day.<br>
# The explanation on how to read and interpret the graphs can found in 'Outbreak-Spread-Explanation' please refer there in case of uncertainty.
#
# Any requests for countries, graphs or data to be added are more then welcome.

# %%
import my_tools as mt

# %% [markdown]
# ## Index
# ---
#
# - [Countries of interest](#interest_info)
# - [Countries with most cases, deaths](#worst_info)
# - [Countries that are recovering](#recovering_info)
# - [Global information](#global_info)

# %% [markdown]
# <a id="interest_info"> </a>
# ## Countries of interest
# ---
#
# This list of countries has been chosen for personal relations within the conutries or as references to trends.

# %%
countries_of_interest = ['China', 'France', 'Italy', 'United States of America', 'Spain', 
                         'United Kingdom', 'Belgium', 'Iran', 'Ukraine', 'South Korea']

countries_of_interest.sort()

# %% [markdown]
# ### New cases and deaths

# %%
mt.plot_spread('daily', countries_of_interest)
mt.plot_spread('weekly', countries_of_interest)

# %% [markdown]
# ### Total cases, deaths

# %%
mt.plot_spread('total', countries_of_interest)
mt.plot_spread('total', countries_of_interest, 'log')

# %% [markdown]
# ### Weekly cases compared to total

# %%
mt.plot_trends(countries_of_interest)
# Out:
# /home/simon/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %% [markdown]
# ### Table with data
#
# - Prevalence = total amount of cases / country popultion
# - Incidence = amount of new cases / country population
# - Mortality = total amount deaths / total amount of cases

# %%
mt.show_table(countries_of_interest)
# Out:
# <style  type="text/css" >
# </style><table id="T_0b595278_7731_11ea_831a_4161f63fd129" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Today</th>        <th class="col_heading level0 col1" >This week</th>        <th class="col_heading level0 col2" >Total</th>        <th class="col_heading level0 col3" >Prevalence</th>        <th class="col_heading level0 col4" >Incidence today</th>        <th class="col_heading level0 col5" >Incidence this week</th>        <th class="col_heading level0 col6" >Mortality</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0b595278_7731_11ea_831a_4161f63fd129level0_row0" class="row_heading level0 row0" rowspan=2>Global</th>
#                         <th id="T_0b595278_7731_11ea_831a_4161f63fd129level1_row0" class="row_heading level1 row0" >Cases</th>
# ...

# %% [markdown]
# <a id="worst_info"> </a>
# [Back to top](#top)
#
# ## Most active countries
#
# This list of countries is created by looking at the 10 countries that have the most amount of new cases, as well as the 10 that have the most amount of new deaths, both in the last week, and getting the intersection of these two lists. Most of the time these list have the same countries in them, in which case the intersection keeps 10.
#
# For this section we will plot the data on the last 40 days, this will be updated later to an automatic system at a later time.

# %%
active_countries = mt.find_active()
amount_days = 6 * 7

# %% [markdown]
# ### New cases and deaths

# %%
mt.plot_spread('daily', active_countries, days=amount_days)
mt.plot_spread('weekly', active_countries, days=amount_days)

# %% [markdown]
# ### Total cases, deaths

# %%
mt.plot_spread('total', active_countries, days=amount_days)
mt.plot_spread('total', active_countries, 'log')

# %% [markdown]
# ### New cases compared to total

# %%
mt.plot_trends(active_countries)
# Out:
# /home/simon/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %% [markdown]
# ### Table with data
#
# - Prevalence = total amount of cases / country popultion
# - Incidence = amount of new cases / country population
# - Mortality = total amount deaths / total amount of cases

# %%
mt.show_table(active_countries)
# Out:
# <style  type="text/css" >
# </style><table id="T_0d82fa22_7731_11ea_831a_4161f63fd129" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Today</th>        <th class="col_heading level0 col1" >This week</th>        <th class="col_heading level0 col2" >Total</th>        <th class="col_heading level0 col3" >Prevalence</th>        <th class="col_heading level0 col4" >Incidence today</th>        <th class="col_heading level0 col5" >Incidence this week</th>        <th class="col_heading level0 col6" >Mortality</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0d82fa22_7731_11ea_831a_4161f63fd129level0_row0" class="row_heading level0 row0" rowspan=2>Global</th>
#                         <th id="T_0d82fa22_7731_11ea_831a_4161f63fd129level1_row0" class="row_heading level1 row0" >Cases</th>
# ...

# %% [markdown]
# <a id="recovered_info"> </a>
# [Back to top](#top)
#
# # Countries that recovered
#
# These list of countries are all that countries that have had no new cases in a certain period of time. We only eliminated 'Cases on an international conveyance Japan' from the list since this was the cruise ship that was marrouned and due to the nature of that situation, it distort the visualizatiuon and make it more confusingto compare the countries.
#
# Though considering most of these countries have not had a lot of cases overall, since there is no country as of yet that has fully beaten the outbreak, we will only show the table for these countries for now.
#
# More will come in the future, whn there are something interesting things to see in this information.

# %%
recovered_countries = mt.find_recovered(3)
mt.show_table(recovered_countries)
# Out:
# <style  type="text/css" >
# </style><table id="T_0d8882c6_7731_11ea_831a_4161f63fd129" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Today</th>        <th class="col_heading level0 col1" >This week</th>        <th class="col_heading level0 col2" >Total</th>        <th class="col_heading level0 col3" >Prevalence</th>        <th class="col_heading level0 col4" >Incidence today</th>        <th class="col_heading level0 col5" >Incidence this week</th>        <th class="col_heading level0 col6" >Mortality</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0d8882c6_7731_11ea_831a_4161f63fd129level0_row0" class="row_heading level0 row0" rowspan=2>Global</th>
#                         <th id="T_0d8882c6_7731_11ea_831a_4161f63fd129level1_row0" class="row_heading level1 row0" >Cases</th>
# ...

# %% [markdown]
# <a id="global_info"> </a>
# [Back to top](#top)
#
# # Global data

# %% [markdown]
# This last section contains data on every country of which data is provided.
# Though the graphs look quite messy in these, it can give a bit of an overview how the disease is spreading throughout the world.
#
# The graphs are quite hectic and for the moment there is no legend. Considering the amount of countries is so large, this needs some other implimentations. Appologies for this, this will be present in a future update.

# %% [markdown]
# ### Global averages
#
#
# To start of with we will plot the global amount for cases and deaths.
#
# - cases_ relative = total cases / world population
# - deaths_relative = total deaths / total cases

# %%
mt.plot_global()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-4db60098cf96> in <module>
# ----> 1 mt.plot_global()
#
# ~/Portfolio/COVID-data/Visualization/my_tools.py in plot_global()
#      80
#      81 def plot_global():
# ---> 82     plot_side_by_side(df_global['cases_total'], df_global['prevalence'], leg=False, title='Global info')
#      83     plot_side_by_side(df_global['deaths_total'], df_global['mortality'], leg=False)
#      84
#
# NameError: name 'plot_side_by_side' is not defined

# %% [markdown]
# As mentioned in the section above.
# There will be no extra explinations on the provided graphs in this section.
#
# Though seeing the death rate ever increasing is an unpleasant sight.
#
# ### New cases and deaths

# %%
mt.plot_spread('daily')
mt.plot_spread('weekly')

# %% [markdown]
# ### Total cases, deaths

# %%
mt.plot_spread('total')
mt.plot_spread('total', scale='log')

# %% [markdown]
# ### New cases compared to total

# %%
mt.plot_trends()

# %% [markdown]
# ### Table with data
#
# - Prevalence = total amount of cases / country popultion
# - Incidence = amount of new cases / country population
# - Mortality = total amount deaths / total amount of cases

# %%
mt.show_table()

# %% [markdown]
# [Back to top](#top)
