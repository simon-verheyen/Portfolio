# %% [markdown]
# <a id="top"> </a>
#
# To view this on a full page, please right-click and 'open in new tab' [this link](#"top").<br/>
# Apologies that the internal hyperlinks don't work in github, this will be investigated in the future.
# # COVID-19 Outbreak Spread
# ---
#
# <a id="division_ID"> </a>
#
# This notebook is part of a toolset to analyse and visualise data on the COVID-19 outbreak and will be run once a day.<br>
# The explanation on how to read and interpret the graphs can found in 'Outbreak-Spread-Explanation' please refer there in case of uncertainty.
#
# Any requests for countries, graphs or data to be added are more then welcome.

# %%
import my_tools as mt

# %% [markdown]
# ## Index
# ---
#
# - [Countries of interest](#interest_info)
# - [Countries with most cases, deaths](#worst_info)
# - [Global information](#global_info)

# %% [markdown]
# <a id="interest_info"> </a>
# ## Countries of interest
# ---
#
# This list of countries has been chosen for personal relations within the conutries or as references to trends.

# %%
countries_of_interest = ['China', 'France', 'Italy', 'United States of America', 'Spain', 
                         'United Kingdom', 'Belgium', 'Iran', 'Ukraine', 'South Korea']

countries_of_interest.sort()

# %% [markdown]
# ### New cases and deaths

# %%
mt.plot_spread('weekly', countries_of_interest)

# %% [markdown]
# ### Total cases, deaths

# %%
mt.plot_spread('total', countries_of_interest)
mt.plot_spread('total_log', countries_of_interest)

# %% [markdown]
# ### Weekly cases compared to total

# %%
mt.plot_trends(countries_of_interest)

# %% [markdown]
# ### Table with data
#
# - Prevalence = total amount of cases / country popultion
# - Incidence = amount of new cases / country population
# - Mortality = total amount deaths / total amount of cases

# %%
mt.show_table(countries_of_interest)
# Out:
# <style  type="text/css" >
# </style><table id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Today</th>        <th class="col_heading level0 col1" >This week</th>        <th class="col_heading level0 col2" >Total</th>        <th class="col_heading level0 col3" >Prevalence</th>        <th class="col_heading level0 col4" >Incidence today</th>        <th class="col_heading level0 col5" >Incidence this week</th>        <th class="col_heading level0 col6" >Mortality</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522level0_row0" class="row_heading level0 row0" rowspan=2>Global</th>
#                         <th id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522level1_row0" class="row_heading level1 row0" >Cases</th>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row0_col0" class="data row0 col0" >75403</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row0_col1" class="data row0 col1" >475282</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row0_col2" class="data row0 col2" >853200</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row0_col3" class="data row0 col3" >    0.011%</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row0_col4" class="data row0 col4" >    0.001%</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row0_col5" class="data row0 col5" >    3.594%</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row0_col6" class="data row0 col6" ></td>
#             </tr>
#             <tr>
#                                 <th id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522level1_row1" class="row_heading level1 row1" >Deaths</th>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row1_col0" class="data row1 col0" >4616</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row1_col1" class="data row1 col1" >25524</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row1_col2" class="data row1 col2" >41887</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row1_col3" class="data row1 col3" ></td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row1_col4" class="data row1 col4" ></td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row1_col5" class="data row1 col5" ></td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row1_col6" class="data row1 col6" >    4.909%</td>
#             </tr>
#             <tr>
#                         <th id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522level0_row2" class="row_heading level0 row2" rowspan=2>Belgium</th>
#                         <th id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522level1_row2" class="row_heading level1 row2" >Cases</th>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row2_col0" class="data row2 col0" >876</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row2_col1" class="data row2 col1" >9032</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row2_col2" class="data row2 col2" >12775</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row2_col3" class="data row2 col3" >    0.112%</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row2_col4" class="data row2 col4" >    0.008%</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row2_col5" class="data row2 col5" >    0.079%</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row2_col6" class="data row2 col6" ></td>
#             </tr>
#             <tr>
#                                 <th id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522level1_row3" class="row_heading level1 row3" >Deaths</th>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row3_col0" class="data row3 col0" >192</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row3_col1" class="data row3 col1" >617</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row3_col2" class="data row3 col2" >705</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row3_col3" class="data row3 col3" ></td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row3_col4" class="data row3 col4" ></td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row3_col5" class="data row3 col5" ></td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row3_col6" class="data row3 col6" >    5.519%</td>
#             </tr>
#             <tr>
#                         <th id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522level0_row4" class="row_heading level0 row4" rowspan=2>China</th>
#                         <th id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522level1_row4" class="row_heading level1 row4" >Cases</th>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row4_col0" class="data row4 col0" >54</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row4_col1" class="data row4 col1" >742</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row4_col2" class="data row4 col2" >82295</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row4_col3" class="data row4 col3" >    0.006%</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row4_col4" class="data row4 col4" >    0.000%</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row4_col5" class="data row4 col5" >    0.000%</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row4_col6" class="data row4 col6" ></td>
#             </tr>
#             <tr>
#                                 <th id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522level1_row5" class="row_heading level1 row5" >Deaths</th>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row5_col0" class="data row5 col0" >1</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row5_col1" class="data row5 col1" >29</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row5_col2" class="data row5 col2" >3310</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row5_col3" class="data row5 col3" ></td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row5_col4" class="data row5 col4" ></td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row5_col5" class="data row5 col5" ></td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row5_col6" class="data row5 col6" >    4.022%</td>
#             </tr>
#             <tr>
#                         <th id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522level0_row6" class="row_heading level0 row6" rowspan=2>France</th>
#                         <th id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522level1_row6" class="row_heading level1 row6" >Cases</th>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row6_col0" class="data row6 col0" >7578</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row6_col1" class="data row6 col1" >32272</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row6_col2" class="data row6 col2" >52128</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row6_col3" class="data row6 col3" >    0.078%</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row6_col4" class="data row6 col4" >    0.011%</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row6_col5" class="data row6 col5" >    0.048%</td>
#                         <td id="T_e920bf96_74f3_11ea_9b3b_1f4adbc50522row6_col6" class="data row6 col6" ></td>
#             </

# %% [markdown]
# <a id="worst_info"> </a>
# [Back to top](#top)
#
# ## Most active countries
#
# This list of countries is created by looking at the 10 countries that have the most amount of new cases, as well as the 10 that have the most amount of new deaths, both in the last week, and getting the intersection of these two lists. Most of the time these list have the same countries in them, in which case the intersection keeps 10.
#
# For this section we will plot the data on the last 40 days, this will be updated later to an automatic system at a later time.

# %%
active_countries = mt.find_active()
amount_days = 6 * 7

# %% [markdown]
# ### New cases and deaths

# %%
mt.plot_spread('weekly', active_countries, days=amount_days)

# %% [markdown]
# ### Total cases, deaths

# %%
mt.plot_spread('total', active_countries, days=amount_days)
mt.plot_spread('total_log', active_countries)

# %% [markdown]
# ### New cases compared to total

# %%
mt.plot_trends(active_countries)

# %% [markdown]
# ### Table with data
#
# - Prevalence = total amount of cases / country popultion
# - Incidence = amount of new cases / country population
# - Mortality = total amount deaths / total amount of cases

# %%
mt.show_table(active_countries)
# Out:
# <style  type="text/css" >
# </style><table id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Today</th>        <th class="col_heading level0 col1" >This week</th>        <th class="col_heading level0 col2" >Total</th>        <th class="col_heading level0 col3" >Prevalence</th>        <th class="col_heading level0 col4" >Incidence today</th>        <th class="col_heading level0 col5" >Incidence this week</th>        <th class="col_heading level0 col6" >Mortality</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522level0_row0" class="row_heading level0 row0" rowspan=2>Global</th>
#                         <th id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522level1_row0" class="row_heading level1 row0" >Cases</th>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row0_col0" class="data row0 col0" >75403</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row0_col1" class="data row0 col1" >475282</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row0_col2" class="data row0 col2" >853200</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row0_col3" class="data row0 col3" >    0.011%</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row0_col4" class="data row0 col4" >    0.001%</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row0_col5" class="data row0 col5" >    3.594%</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row0_col6" class="data row0 col6" ></td>
#             </tr>
#             <tr>
#                                 <th id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522level1_row1" class="row_heading level1 row1" >Deaths</th>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row1_col0" class="data row1 col0" >4616</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row1_col1" class="data row1 col1" >25524</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row1_col2" class="data row1 col2" >41887</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row1_col3" class="data row1 col3" ></td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row1_col4" class="data row1 col4" ></td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row1_col5" class="data row1 col5" ></td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row1_col6" class="data row1 col6" >    4.909%</td>
#             </tr>
#             <tr>
#                         <th id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522level0_row2" class="row_heading level0 row2" rowspan=2>Belgium</th>
#                         <th id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522level1_row2" class="row_heading level1 row2" >Cases</th>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row2_col0" class="data row2 col0" >876</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row2_col1" class="data row2 col1" >9032</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row2_col2" class="data row2 col2" >12775</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row2_col3" class="data row2 col3" >    0.112%</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row2_col4" class="data row2 col4" >    0.008%</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row2_col5" class="data row2 col5" >    0.079%</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row2_col6" class="data row2 col6" ></td>
#             </tr>
#             <tr>
#                                 <th id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522level1_row3" class="row_heading level1 row3" >Deaths</th>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row3_col0" class="data row3 col0" >192</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row3_col1" class="data row3 col1" >617</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row3_col2" class="data row3 col2" >705</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row3_col3" class="data row3 col3" ></td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row3_col4" class="data row3 col4" ></td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row3_col5" class="data row3 col5" ></td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row3_col6" class="data row3 col6" >    5.519%</td>
#             </tr>
#             <tr>
#                         <th id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522level0_row4" class="row_heading level0 row4" rowspan=2>France</th>
#                         <th id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522level1_row4" class="row_heading level1 row4" >Cases</th>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row4_col0" class="data row4 col0" >7578</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row4_col1" class="data row4 col1" >32272</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row4_col2" class="data row4 col2" >52128</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row4_col3" class="data row4 col3" >    0.078%</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row4_col4" class="data row4 col4" >    0.011%</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row4_col5" class="data row4 col5" >    0.048%</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row4_col6" class="data row4 col6" ></td>
#             </tr>
#             <tr>
#                                 <th id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522level1_row5" class="row_heading level1 row5" >Deaths</th>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row5_col0" class="data row5 col0" >499</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row5_col1" class="data row5 col1" >2663</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row5_col2" class="data row5 col2" >3523</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row5_col3" class="data row5 col3" ></td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row5_col4" class="data row5 col4" ></td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row5_col5" class="data row5 col5" ></td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row5_col6" class="data row5 col6" >    6.758%</td>
#             </tr>
#             <tr>
#                         <th id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522level0_row6" class="row_heading level0 row6" rowspan=2>Germany</th>
#                         <th id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522level1_row6" class="row_heading level1 row6" >Cases</th>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row6_col0" class="data row6 col0" >5453</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row6_col1" class="data row6 col1" >38154</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row6_col2" class="data row6 col2" >67366</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row6_col3" class="data row6 col3" >    0.081%</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row6_col4" class="data row6 col4" >    0.007%</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row6_col5" class="data row6 col5" >    0.046%</td>
#                         <td id="T_ea869cde_74f3_11ea_9b3b_1f4adbc50522row6_col6" class="data row6 col6" ></td>

# %% [markdown]
# <a id="global_info"> </a>
# [Back to top](#top)
#
# # Global data

# %% [markdown]
# This last section contains data on every country of which data is provided.
# Though the graphs look quite messy in these, it can give a bit of an overview how the disease is spreading throughout the world.
#
# The graphs are quite hectic and for the moment there is no legend. Considering the amount of countries is so large, this needs some other implimentations. Appologies for this, this will be present in a future update.

# %% [markdown]
# ### Global averages
#
#
# To start of with we will plot the global amount for cases and deaths.
#
# - cases_ relative = total cases / world population
# - deaths_relative = total deaths / total cases

# %%
mt.plot_global()

# %% [markdown]
# As mentioned in the section above.
# There will be no extra explinations on the provided graphs in this section.
#
# Though seeing the death rate ever increasing is an unpleasant sight.
#
# ### New cases and deaths

# %%
mt.plot_spread('daily')
mt.plot_spread('weekly')

# %% [markdown]
# ### Total cases, deaths

# %%
mt.plot_spread('total')
mt.plot_spread('total_log')

# %% [markdown]
# ### New cases compared to total

# %%
mt.plot_trends()

# %% [markdown]
# ### Table with data
#
# - Prevalence = total amount of cases / country popultion
# - Incidence = amount of new cases / country population
# - Mortality = total amount deaths / total amount of cases

# %%
mt.show_table()
# Out:
# <style  type="text/css" >
# </style><table id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522" ><thead>    <tr>        <th class="blank" ></th>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Today</th>        <th class="col_heading level0 col1" >This week</th>        <th class="col_heading level0 col2" >Total</th>        <th class="col_heading level0 col3" >Prevalence</th>        <th class="col_heading level0 col4" >Incidence today</th>        <th class="col_heading level0 col5" >Incidence this week</th>        <th class="col_heading level0 col6" >Mortality</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522level0_row0" class="row_heading level0 row0" rowspan=2>Global</th>
#                         <th id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522level1_row0" class="row_heading level1 row0" >Cases</th>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row0_col0" class="data row0 col0" >75403</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row0_col1" class="data row0 col1" >475282</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row0_col2" class="data row0 col2" >853200</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row0_col3" class="data row0 col3" >    0.011%</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row0_col4" class="data row0 col4" >    0.001%</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row0_col5" class="data row0 col5" >    3.594%</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row0_col6" class="data row0 col6" ></td>
#             </tr>
#             <tr>
#                                 <th id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522level1_row1" class="row_heading level1 row1" >Deaths</th>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row1_col0" class="data row1 col0" >4616</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row1_col1" class="data row1 col1" >25524</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row1_col2" class="data row1 col2" >41887</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row1_col3" class="data row1 col3" ></td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row1_col4" class="data row1 col4" ></td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row1_col5" class="data row1 col5" ></td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row1_col6" class="data row1 col6" >    4.909%</td>
#             </tr>
#             <tr>
#                         <th id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522level0_row2" class="row_heading level0 row2" rowspan=2>Afghanistan</th>
#                         <th id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522level1_row2" class="row_heading level1 row2" >Cases</th>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row2_col0" class="data row2 col0" >25</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row2_col1" class="data row2 col1" >126</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row2_col2" class="data row2 col2" >166</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row2_col3" class="data row2 col3" >    0.000%</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row2_col4" class="data row2 col4" >    0.000%</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row2_col5" class="data row2 col5" >    0.000%</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row2_col6" class="data row2 col6" ></td>
#             </tr>
#             <tr>
#                                 <th id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522level1_row3" class="row_heading level1 row3" >Deaths</th>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row3_col0" class="data row3 col0" >0</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row3_col1" class="data row3 col1" >3</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row3_col2" class="data row3 col2" >4</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row3_col3" class="data row3 col3" ></td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row3_col4" class="data row3 col4" ></td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row3_col5" class="data row3 col5" ></td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row3_col6" class="data row3 col6" >    2.410%</td>
#             </tr>
#             <tr>
#                         <th id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522level0_row4" class="row_heading level0 row4" rowspan=2>Albania</th>
#                         <th id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522level1_row4" class="row_heading level1 row4" >Cases</th>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row4_col0" class="data row4 col0" >20</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row4_col1" class="data row4 col1" >143</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row4_col2" class="data row4 col2" >243</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row4_col3" class="data row4 col3" >    0.008%</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row4_col4" class="data row4 col4" >    0.001%</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row4_col5" class="data row4 col5" >    0.005%</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row4_col6" class="data row4 col6" ></td>
#             </tr>
#             <tr>
#                                 <th id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522level1_row5" class="row_heading level1 row5" >Deaths</th>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row5_col0" class="data row5 col0" >3</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row5_col1" class="data row5 col1" >11</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row5_col2" class="data row5 col2" >15</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row5_col3" class="data row5 col3" ></td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row5_col4" class="data row5 col4" ></td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row5_col5" class="data row5 col5" ></td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row5_col6" class="data row5 col6" >    6.173%</td>
#             </tr>
#             <tr>
#                         <th id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522level0_row6" class="row_heading level0 row6" rowspan=2>Algeria</th>
#                         <th id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522level1_row6" class="row_heading level1 row6" >Cases</th>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row6_col0" class="data row6 col0" >73</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row6_col1" class="data row6 col1" >395</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row6_col2" class="data row6 col2" >584</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row6_col3" class="data row6 col3" >    0.001%</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row6_col4" class="data row6 col4" >    0.000%</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row6_col5" class="data row6 col5" >    0.001%</td>
#                         <td id="T_ef8bc7c2_74f3_11ea_9b3b_1f4adbc50522row6_col6" class="data row6 col6" ></td>
#             </tr>

# %% [markdown]
# [Back to top](#top)
