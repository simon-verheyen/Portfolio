# %%
import pandas as pd
import datetime

df_cases_new = pd.read_csv('data/cases_new.csv')
df_cases_new['Date'] = df_cases_new['Date'].astype('datetime64[ns]')
df_cases_new = df_cases_new.set_index('Date')

df_deaths_new = pd.read_csv('data/deaths_new.csv')
df_deaths_new['Date'] = df_deaths_new['Date'].astype('datetime64[ns]') 
df_deaths_new = df_deaths_new.set_index('Date')

df_populations = pd.read_csv('data/populations_2018.csv').set_index('Countries')

dates = df_cases_new.index
countries = df_cases_new.columns

today = datetime.date.today() - datetime.timedelta(days=1)

# %% [markdown]
# # Create total

# %%
df_cases_total = df_cases_new.copy()
df_deaths_total = df_deaths_new.copy()

for country in countries:
    cases = 0
    deaths = 0
    
    for date in dates:
        cases += df_cases_new.at[date, country]
        deaths += df_deaths_new.at[date, country]
        
        df_cases_total.at[date, country] = cases
        df_deaths_total.at[date, country] = deaths
        
display(df_cases_total)
display(df_deaths_total)
# Out:
#             Afghanistan  Angola  Albania  Andorra  Algeria  Anguilla  \
# Date
# 2019-12-31            0       0        0        0        0         0
# 2020-01-01            0       0        0        0        0         0
# 2020-01-02            0       0        0        0        0         0
# 2020-01-03            0       0        0        0        0         0
# 2020-01-04            0       0        0        0        0         0
# ...                 ...     ...      ...      ...      ...       ...
# 2020-03-27           75       3      174      224      305         2
# 2020-03-28           91       4      186      267      305         2
# 2020-03-29          106       4      197      308      409         2
# 2020-03-30          114       7      212      334      454         2
# 2020-03-31          141       7      223      370      511         2
#
#             Antigua_and_Barbuda  Argentina  Armenia  Aruba  ...  \
# Date                                                        ...
# 2019-12-31                    0          0        0      0  ...
# 2020-01-01                    0          0        0      0  ...
# 2020-01-02                    0          0        0      0  ...
# 2020-01-03                    0          0        0      0  ...
# 2020-01-04                    0          0        0      0  ...
# ...                         ...        ...      ...    ...  ...
# 2020-03-27                    7        589      329     28  ...
# 2020-03-28                    7        690      372     28  ...
# 2020-03-29                    7        745      424     28  ...
# 2020-03-30                    7        820      424     50  ...
# 2020-03-31                    7        966      482     50  ...
#
#             United_Kingdom  United_Republic_of_Tanzania  \
# Date
# 2019-12-31               0                            0
# 2020-01-01               0                            0
# 2020-01-02               0                            0
# 2020-01-03               0                            0
# 2020-01-04               0                            0
# ...                    ...                          ...
# 2020-03-27           11658                           13
# 2020-03-28           14543                           13
# 2020-03-29           17089                           13
# 2020-03-30           19522                           14
# 2020-03-31           22141                           19
#
#             United_States_of_America  United_States_Virgin_Islands  Uruguay  \
# Date
# 2019-12-31                         0                             0        0
# 2020-01-01                         0                             0        0
# 2020-01-02                         0                             0        0
# 2020-01-03                         0                             0        0
# 2020-01-04                         0                             0        0
# ...                              ...                           ...      ...
# 2020-03-27                     85991                            17      238
# 2020-03-28                    104686                            19      238
# 2020-03-29                    124665                            22      304
# 2020-03-30                    143025                            30      309
# 2020-03-31                    164620                            30      320
#
#             Uzbekistan  Venezuela  Vietnam  Zambia  Zimbabwe
# Date
# 2019-12-31           0          0        0       0         0
# 2020-01-01           0          0        0       0         0
# 2020-01-02           0          0        0       0         0
# 2020-01-03           0          0        0       0         0
# 2020-01-04           0          0        0       0         0
# ...                ...        ...      ...     ...       ...
# 2020-03-27          83        107      153      14         3
# 2020-03-28         104        119      169      16         5
# 2020-03-29         133        119      223      28         7
# 2020-03-30         145        119      228      29         7
# 2020-03-31         149        135      229      35         7
#
# [92 rows x 199 columns]
#             Afghanistan  Angola  Albania  Andorra  Algeria  Anguilla  \
# Date
# 2019-12-31            0       0        0        0        0         0
# 2020-01-01            0       0        0        0        0         0
# 2020-01-02            0       0        0        0        0         0
# 2020-01-03            0       0        0        0        0         0
# 2020-01-04            0       0        0        0        0         0
# ...                 ...     ...      ...      ...      ...       ...
# 2020-03-27            1       0        6        3       21         0
# 2020-03-28            2       0        9        3       21         0
# 2020-03-29            3       0       10        4       26         0
# 2020-03-30            4       2       10        6       29         0
# 2020-03-31            4       2       12        8       31         0
#
#             Antigua_and_Barbuda  Argentina  Armenia  Aruba  ...  \
# Date                                                        ...
# 2019-12-31                    0          0        0      0  ...
# 2020-01-01                    0          0        0      0  ...
# 2020-01-02                    0          0        0      0  ...
# 2020-01-03                    0          0        0      0  ...
# 2020-01-04                    0          0        0      0  ...
# ...                         ...        ...      ...    ...  ...
# 2020-03-27                    0         12        1      0  ...
# 2020-03-28                    0         17        1      0  ...
# 2020-03-29                    0         19        3      0  ...
# 2020-03-30                    0         20        3      0  ...
# 2020-03-31                    0         24        3      0  ...
#
#             United_Kingdom  United_Republic_of_Tanzania  \
# Date
# 2019-12-31               0                            0
# 2020-01-01               0                            0
# 2020-01-02               0                            0
# 2020-01-03               0                            0
# 2020-01-04               0                            0
# ...                    ...                          ...
# 2020-03-27             578                            0
# 2020-03-28             759                            0
# 2020-03-29            1019                            1
# 2020-03-30            1228                            1
# 2020-03-31            1408                            1
#
#             United_States_of_America  United_States_Virgin_Islands  Uruguay  \
# Date
# 2019-12-31                         0                             0        0
# 2020-01-01                         0                             0        0
# 2020-01-02                         0                             0        0
# 2020-01-03                         0                             0        0
# 2020-01-04                         0                             0        0
# ...                              ...                           ...      ...
# 2020-03-27                      1296                             0        0
# 2020-03-28                      1707                             0        0
# 2020-03-29                      2191                             0        0
# 2020-03-30                      2509                             0        1
# 2020-03-31                      3170                             0        1
#
#             Uzbekistan  Venezuela  Vietnam  Zambia  Zimbabwe
# Date
# 2019-12-31           0          0        0       0         0
# 2020-01-01           0          0        0       0         0
# 2020-01-02           0          0        0       0         0
# 2020-01-03           0          0        0       0         0
# 2020-01-04           0          0        0       0         0
# ...                ...        ...      ...     ...       ...
# 2020-03-27           0          1        0       0         1
# 2020-03-28           0          1        0       0         1
# 2020-03-29           1          1        0       0         1
# 2020-03-30           1          1        0       0         1
# 2020-03-31           2          3        0       0         1
#
# [92 rows x 199 columns]

# %% [markdown]
# # Create weekly

# %%
dates_weekly = []

start_date = today
end_date = start_date - datetime.timedelta(days=7)

while end_date > df_cases_new.index[0]:
    dates_weekly.append(start_date)
    
    start_date = end_date
    end_date = start_date - datetime.timedelta(days=7)

dates_weekly.reverse()

struct_cases_weekly = [('Date', dates_weekly)]
struct_deaths_weekly = [('Date', dates_weekly)]

for country in countries:
    cases_weekly = []
    deaths_weekly = []
    
    for date in dates_weekly:
        end_date = date - datetime.timedelta(days=7)
        
        cases_weekly.append(df_cases_new.loc[end_date:date, country].sum())
        deaths_weekly.append(df_deaths_new.loc[end_date:date, country].sum())
    
    struct_cases_weekly.append((country, cases_weekly))
    struct_deaths_weekly.append((country, deaths_weekly))

d_cases = {title: content for (title, content) in struct_cases_weekly}
d_deaths = {title: content for (title, content) in struct_deaths_weekly}

df_cases_weekly = pd.DataFrame(d_cases).set_index('Date')
df_deaths_weekly = pd.DataFrame(d_deaths).set_index('Date')

display(df_cases_weekly)
display(df_deaths_weekly)
# Out:
#             Afghanistan  Angola  Albania  Andorra  Algeria  Anguilla  \
#
#             Antigua_and_Barbuda  Argentina  Armenia  Aruba  ...  \
# Date                                                        ...
# 2020-01-13                    0          0        0      0  ...
# 2020-01-20                    0          0        0      0  ...
# 2020-01-27                    0          0        0      0  ...
# 2020-02-03                    0          0        0      0  ...
# 2020-02-10                    0          0        0      0  ...
# 2020-02-17                    0          0        0      0  ...
# 2020-02-24                    0          0        0      0  ...
# 2020-03-02                    0          0        0      0  ...
# 2020-03-09                    0          1        0      0  ...
# 2020-03-16                    0          1        0      0  ...
# 2020-03-23                    0          2        0      0  ...
# 2020-03-30                    0         16        3      0  ...
#
#             United_Kingdom  United_Republic_of_Tanzania  \
# Date
# 2020-01-13               0                            0
# 2020-01-20               0                            0
# 2020-01-27               0                            0
# 2020-02-03               0                            0
# 2020-02-10               0                            0
# 2020-02-17               0                            0
# 2020-02-24               0                            0
# 2020-03-02               0                            0
# 2020-03-09               3                            0
# 2020-03-16              33                            0
# 2020-03-23             260                            0
# 2020-03-30             995                            1
#
#             United_States_of_America  United_States_Virgin_Islands  Uruguay  \
# Date
# 2020-01-13                         0                             0        0
# 2020-01-20                         0                             0        0
# 2020-01-27                         0                             0        0
# 2020-02-03                         0                             0        0
# 2020-02-10                         0                             0        0
# 2020-02-17                         0                             0        0
# 2020-02-24                         0                             0        0
# 2020-03-02                         2                             0        0
# 2020-03-09                        20                             0        0
# 2020-03-16                        52                             0        0
# 2020-03-23                       414                             0        0
# 2020-03-30                      2169                             0        1
#
#             Uzbekistan  Venezuela  Vietnam  Zambia  Zimbabwe
# Date
# 2020-01-13           0          0        0       0         0
# 2020-01-20           0          0        0       0         0
# 2020-01-27           0          0        0       0         0
# 2020-02-03           0          0        0       0         0
# 2020-02-10           0          0        0       0         0
# 2020-02-17           0          0        0       0         0
# 2020-02-24           0          0        0       0         0
# 2020-03-02           0          0        0       0         0
# 2020-03-09           0          0        0       0         0
# 2020-03-16           0          0        0       0         0
# 2020-03-23           0          0        0       0         0
# 2020-03-30           1          1        0       0         1
#
# [12 rows x 199 columns]

# %% [markdown]
# # Create Relative

# %%
df_cases_relative = df_cases_new.copy().astype('float')
df_deaths_relative = df_deaths_new.copy().astype('float')

for country in countries:
    ok = (df_populations.at[country, 'Populations'] != 0)
    
    for date in dates:
        if df_cases_total.at[date, country] != 0:
            rel_value = df_deaths_total.at[date, country] / df_cases_total.at[date, country]
            df_deaths_relative.at[date, country] = rel_value
        else:
            df_deaths_relative.at[date, country] = 0

        if ok:
            df_cases_relative.at[date, country] = df_cases_total.at[date, country] / df_populations.at[country, 'Populations']
        else: 
            df_cases_relative.at[date, country] = 0
            
display(df_cases_relative)
display(df_deaths_relative)
# Out:
#             Afghanistan        Angola   Albania   Andorra   Algeria  Anguilla  \
# Date
# 2019-12-31     0.000000  0.000000e+00  0.000000  0.000000  0.000000       0.0
# 2020-01-01     0.000000  0.000000e+00  0.000000  0.000000  0.000000       0.0
# 2020-01-02     0.000000  0.000000e+00  0.000000  0.000000  0.000000       0.0
# 2020-01-03     0.000000  0.000000e+00  0.000000  0.000000  0.000000       0.0
# 2020-01-04     0.000000  0.000000e+00  0.000000  0.000000  0.000000       0.0
# ...                 ...           ...       ...       ...       ...       ...
# 2020-03-27     0.000002  9.737174e-08  0.000061  0.002909  0.000007       0.0
# 2020-03-28     0.000002  1.298290e-07  0.000065  0.003467  0.000007       0.0
# 2020-03-29     0.000003  1.298290e-07  0.000069  0.004000  0.000010       0.0
.000000  0.000000  0.000000  0.000000  0.000000       0.0
# ...                 ...       ...       ...       ...       ...       ...
# 2020-03-27     0.013333  0.000000  0.034483  0.013393  0.068852       0.0
# 2020-03-28     0.021978  0.000000  0.048387  0.011236  0.068852       0.0
# 2020-03-29     0.028302  0.000000  0.050761  0.012987  0.063570       0.0
# 2020-03-30     0.035088  0.285714  0.047170  0.017964  0.063877       0.0
# 2020-03-31     0.028369  0.285714  0.053812  0.021622  0.060665       0.0
#
#             Antigua_and_Barbuda  Argentina   Armenia  Aruba  ...  \
# Date                                                         ...
# 2019-12-31                  0.0   0.000000  0.000000    0.0  ...
# 2020-01-01                  0.0   0.000000  0.000000    0.0  ...
# 2020-01-02                  0.0   0.000000  0.000000    0.0  ...
# 2020-01-03                  0.0   0.000000  0.000000    0.0  ...
# 2020-01-04                  0.0   0.000000  0.000000    0.0  ...
# ...                         ...        ...       ...    ...  ...
# 2020-03-27                  0.0   0.020374  0.003040    0.0  ...
# 2020-03-28                  0.0   0.024638  0.002688    0.0  ...
# 2020-03-29                  0.0   0.025503  0.007075    0.0  ...
# 2020-03-30                  0.0   0.024390  0.007075    0.0  ...
# 2020-03-31                  0.0   0.024845  0.006224    0.0  ...
#
#             United_Kingdom  United_Republic_of_Tanzania  \
# Date
# 2019-12-31        0.000000                     0.000000
# 2020-01-01        0.000000                     0.000000
# 2020-01-02        0.000000                     0.000000
# 2020-01-03        0.000000                     0.000000
# 2020-01-04        0.000000                     0.000000
# ...                    ...                          ...
# 2020-03-27        0.049580                     0.000000
# 2020-03-28        0.052190                     0.000000
# 2020-03-29        0.059629                     0.076923
# 2020-03-30        0.062903                     0.071429
# 2020-03-31        0.063592                     0.052632
#
#             United_States_of_America  United_States_Virgin_Islands   Uruguay  \
# Date
# 2019-12-31                  0.000000                           0.0  0.000000
# 2020-01-01                  0.000000                           0.0  0.000000
# 2020-01-02                  0.000000                           0.0  0.000000
# 2020-01-03                  0.000000                           0.0  0.000000
# 2020-01-04                  0.000000                           0.0  0.000000
# ...                              ...                           ...       ...
# 2020-03-27                  0.015071                           0.0  0.000000
# 2020-03-28                  0.016306                           0.0  0.000000
# 2020-03-29                  0.017575                           0.0  0.000000
# 2020-03-30                  0.017542                           0.0  0.003236
# 2020-03-31                  0.019256                           0.0  0.003125
#
#             Uzbekistan  Venezuela  Vietnam  Zambia  Zimbabwe
# Date
# 2019-12-31    0.000000   0.000000      0.0     0.0  0.000000
# 2020-01-01    0.000000   0.000000      0.0     0.0  0.000000
# 2020-01-02    0.000000   0.000000      0.0     0.0  0.000000
# 2020-01-03    0.000000   0.000000      0.0     0.0  0.000000
# 2020-01-04    0.000000   0.000000      0.0     0.0  0.000000
# ...                ...        ...      ...     ...       ...
# 2020-03-27    0.000000   0.009346      0.0     0.0  0.333333
# 2020-03-28    0.000000   0.008403      0.0     0.0  0.200000
# 2020-03-29    0.007519   0.008403      0.0     0.0  0.142857
# 2020-03-30    0.006897   0.008403      0.0     0.0  0.142857
# 2020-03-31    0.013423   0.022222      0.0     0.0  0.142857
#
# [92 rows x 199 columns]

# %% [markdown]
# # From thresholds

# %%
dict_cases = {}
dict_deaths = {}

for country in countries:
    dict_cases[country] = df_cases_total.loc[df_cases_total[country] > 100][country].reset_index(drop=True)
    dict_deaths[country] = df_deaths_total.loc[df_deaths_total[country] > 10][country].reset_index(drop=True)

df_cases_threshold = pd.DataFrame(dict_cases)
df_deaths_threshold = pd.DataFrame(dict_deaths)

df_cases_threshold.dropna(axis=0, how='all', subset=None, inplace=True)
df_deaths_threshold.dropna(axis=0, how='all', subset=None, inplace=True)

display(df_cases_threshold)
display(df_deaths_threshold)
# Out:
#     Afghanistan  Angola  Albania  Andorra  Algeria  Anguilla  \
# 0         106.0     NaN    123.0    113.0    102.0       NaN
# 1         114.0     NaN    146.0    133.0    189.0       NaN
# 2         141.0     NaN    174.0    164.0    231.0       NaN
# 3           NaN     NaN    186.0    188.0    264.0       NaN
# 4           NaN     NaN    197.0    224.0    305.0       NaN
# ..          ...     ...      ...      ...      ...       ...
# 68          NaN     NaN      NaN      NaN      NaN       NaN
# 69          NaN     NaN      NaN      NaN      NaN       NaN
# 70          NaN     NaN      NaN      NaN      NaN       NaN
# 71          NaN     NaN      NaN      NaN      NaN       NaN
# 72          NaN     NaN      NaN      NaN      NaN       NaN
#
#     Antigua_and_Barbuda  Argentina  Armenia  Aruba  ...  United_Kingdom  \
# 0                   NaN      128.0    115.0    NaN  ...           115.0
# 1                   NaN      158.0    122.0    NaN  ...           163.0
# 2                   NaN      225.0    136.0    NaN  ...           206.0
# 3                   NaN      266.0    160.0    NaN  ...           273.0
# 4                   NaN      301.0    190.0    NaN  ...           321.0
# ..                  ...        ...      ...    ...  ...             ...
# 68                  NaN        NaN      NaN    NaN  ...             NaN
# 69                  NaN        NaN      NaN    NaN  ...             NaN
# 70                  NaN        NaN      NaN    NaN  ...             NaN
# 71                  NaN        NaN      NaN    NaN  ...             NaN
# 72                  NaN        NaN      NaN    NaN  ...             NaN
#
#     United_Republic_of_Tanzania  United_States_of_America  \
# 0                           NaN                     103.0
# 1                           NaN                     125.0
# 2                           NaN                     159.0
# 3                           NaN                     233.0
# 4                           NaN                     338.0
# ..                          ...                       ...
# 68                          NaN                       NaN
# 69                          NaN                       NaN
# 70                          NaN                       NaN
# 71                          NaN                       NaN
# 72                          NaN                       NaN
#
#     United_States_Virgin_Islands  Uruguay  Uzbekistan  Venezuela  Vietnam  \
# 0                            NaN    110.0       104.0      106.0    118.0
# 1                            NaN    135.0       133.0      107.0    123.0
# 2                            NaN    158.0       145.0      119.0    134.0
# 3                            NaN    162.0       149.0      119.0    148.0
# 4                            NaN    189.0         NaN      119.0    153.0
# ..                           ...      ...         ...        ...      ...
# 68                           NaN      NaN         NaN        NaN      NaN
# 69                           NaN      NaN         NaN        NaN      NaN
# 70                           NaN      NaN         NaN        NaN      NaN
# 71                           NaN      NaN         NaN        NaN      NaN
# 72                           NaN      NaN         NaN        NaN      NaN
#
#     Zambia  Zimbabwe
# 0      NaN       NaN
# 1      NaN       NaN
# 2      NaN       NaN
# 3      NaN       NaN
# 4      NaN       NaN
# ..     ...       ...
# 68     NaN       NaN
# 69     NaN       NaN
# 70     NaN       NaN
# 71     NaN       NaN
# 72     NaN       NaN
#
# [73 rows x 199 columns]
#     Afghanistan  Angola  Albania  Andorra  Algeria  Anguilla  \
# 0           NaN     NaN     12.0      NaN     15.0       NaN
# 1           NaN     NaN      NaN      NaN     17.0       NaN
# 2           NaN     NaN      NaN      NaN     17.0       NaN
# 3           NaN     NaN      NaN      NaN     17.0       NaN
# 4           NaN     NaN      NaN      NaN     21.0       NaN
# ..          ...     ...      ...      ...      ...       ...
# 65          NaN     NaN      NaN      NaN      NaN       NaN
# 66          NaN     NaN      NaN      NaN      NaN       NaN
# 67          NaN     NaN      NaN      NaN      NaN       NaN
# 68          NaN     NaN      NaN      NaN      NaN       NaN
# 69          NaN     NaN      NaN      NaN      NaN       NaN
#
#     Antigua_and_Barbuda  Argentina  Armenia  Aruba  ...  United_Kingdom  \
# 0                   NaN       12.0      NaN    NaN  ...            21.0
# 1                   NaN       17.0      NaN    NaN  ...            35.0
# 2                   NaN       19.0      NaN    NaN  ...            55.0
# 3                   NaN       20.0      NaN    NaN  ...            60.0
# 4                   NaN       24.0      NaN    NaN  ...           103.0
# ..                  ...        ...      ...    ...  ...             ...
# 65                  NaN        NaN      NaN    NaN  ...             NaN
# 66                  NaN        NaN      NaN    NaN  ...             NaN
# 67                  NaN        NaN      NaN    NaN  ...             NaN
# 68                  NaN        NaN      NaN    NaN  ...             NaN
# 69                  NaN        NaN      NaN    NaN  ...             NaN
#
#     United_Republic_of_Tanzania  United_States_of_America  \
# 0                           NaN                      11.0
# 1                           NaN                      12.0
# 2                           NaN                      14.0
# 3                           NaN                      17.0
# 4                           NaN                      21.0
# ..                          ...                       ...
# 65                          NaN                       NaN
# 66                          NaN                       NaN
# 67                          NaN                       NaN
# 68                          NaN                       NaN
# 69                          NaN                       NaN
#
#     United_States_Virgin_Islands  Uruguay  Uzbekistan  Venezuela  Vietnam  \
# 0                            NaN      NaN         NaN        NaN      NaN
# 1                            NaN      NaN         NaN        NaN      NaN
# 2                            NaN      NaN         NaN        NaN      NaN
# 3                            NaN      NaN         NaN        NaN      NaN
# 4                            NaN      NaN         NaN        NaN      NaN
# ..                           ...      ...         ...        ...      ...
# 65                           NaN      NaN         NaN        NaN      NaN
# 66                           NaN      NaN         NaN        NaN      NaN
# 67                           NaN      NaN         NaN        NaN      NaN
# 68                           NaN      NaN         NaN        NaN      NaN
# 69                           NaN      NaN         NaN        NaN      NaN
#
#     Zambia  Zimbabwe
# 0      NaN       NaN
# 1      NaN       NaN
# 2      NaN       NaN
# 3      NaN       NaN
# 4      NaN       NaN
# ..     ...       ...
# 65     NaN       NaN
# 66     NaN       NaN
# 67     NaN       NaN
# 68     NaN       NaN
# 69     NaN       NaN
#
# [70 rows x 199 columns]

# %% [markdown]
# # Global data

# %%
d = {}
global_pop = df_populations.sum(axis=0).values

d['Date'] = df_cases_new.index

d['cases_new'] = df_cases_new.sum(axis=1).values
d['cases_total'] = df_cases_total.sum(axis=1).values
d['cases_relative'] = (df_cases_total.sum(axis=1).values / global_pop)

d['deaths_new']  = df_deaths_new.sum(axis=1).values
d['deaths_total']  = df_deaths_total.sum(axis=1).values
d['deaths_relative']  = (df_deaths_total.sum(axis=1) / df_cases_total.sum(axis=1)).values

df_global_data = pd.DataFrame(d).set_index('Date')

# %% [markdown]
# # Saving

# %%
df_cases_total.to_csv('data/cases_total.csv')
df_cases_weekly.to_csv('data/cases_weekly.csv')
df_cases_relative.to_csv('data/cases_relative.csv')
df_cases_threshold.to_csv('data/cases_threshold.csv', index=False)

df_deaths_total.to_csv('data/deaths_total.csv')
df_deaths_weekly.to_csv('data/deaths_weekly.csv')
df_deaths_relative.to_csv('data/deaths_relative.csv')
df_deaths_threshold.to_csv('data/deaths_threshold.csv', index=False)

df_global_data.to_csv('data/global_data.csv')
