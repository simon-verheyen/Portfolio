# %%
from dataframe_management import get_global_data, get_country_data
import matplotlib.pyplot as plt

# %%
global_data = get_global_data(['av_child_per_mother'])

# %%
plt.plot(global_mort)
plt.xlabel('Year')
plt.ylabel('global average child mortality')
plt.show()
plt.plot(global_fert)
plt.xlabel('Year')
plt.ylabel('global average child born per mother')
plt.show()

# %%
plt.plot(global_data)
