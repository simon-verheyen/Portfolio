# %% [markdown]
# # Standard start
#
# The dataframe_management script extracts the requested data in one df, indexed by year for either global or country specific.
#
# Possible criteria:
# 'child_mortality' 'av_life_expencatcy' 'av_child_per_mother' 'income_per_person' 'population'
#
# The my_tools script contains small functions to clean up data or plot graphs.

# %%
import data_management as df_mg
import my_tools as mt

# %%
be_pop = df_mg.get_country_data('Belgium', ['child_mortality', 'av_life_expectancy', 'population'],1900,1950)
be_pop_norm = mt.normalize_columns(be_pop)
be_pop_norm.name = 'Belgium'

de_pop = df_mg.get_country_data('Germany', ['child_mortality', 'av_life_expectancy', 'population'],1900,1950)
de_pop_norm = mt.normalize_columns(de_pop)
de_pop_norm.name

fr_pop = df_mg.get_country_data('France', ['child_mortality', 'av_life_expectancy', 'population'],1900,1950)
fr_pop_norm = mt.normalize_columns(de_pop)

ru_pop = df_mg.get_country_data('Russia', ['child_mortality', 'av_life_expectancy', 'population'],1900,1950)
ru_pop_norm = mt.normalize_columns(de_pop)

# %%
mt.plot_side_by_side(be_pop_norm, fr_pop_norm)
mt.plot_side_by_side(de_pop_norm, ru_pop_norm)
